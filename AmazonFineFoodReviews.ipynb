# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from tqdm.notebook import tqdm
sns.set()

# %%
#create connection to sql database
conn = sqlite3.connect('database.sqlite')

# %%
q = """SELECT name FROM sqlite_master WHERE type='table'"""
tables = pd.read_sql_query(q,conn)

# %%
tables
# Out:
#       name
# 0  Reviews

# %%
q = """SELECT * FROM Reviews WHERE Score != 3"""
df = pd.read_sql_query(q,conn)
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
#568454
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525814 entries, 0 to 525813
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      525814 non-null  int64
#  1   ProductId               525814 non-null  object
#  2   UserId                  525814 non-null  object
#  3   ProfileName             525814 non-null  object
#  4   HelpfulnessNumerator    525814 non-null  int64
#  5   HelpfulnessDenominator  525814 non-null  int64
#  6   Score                   525814 non-null  int64
#  7   Time                    525814 non-null  int64
#  8   Summary                 525814 non-null  object
#  9   Text                    525814 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 40.1+ MB

# %% [markdown]
# 1. Id - the id of the row
# 2. ProductId- the id of the particular product
# 3. UserId - the id of the user
# 4. ProfileName - the profile name of the user
# 5. HelpfulnessNumerator - the no of user who found the review helpful
# 6. HelpfulnessDenominator - the no of user who voted the answer
# 7. Score - the rating given by the user to the product
# 8. Time - the time when the review was added
# 9. Summary -  the title of the review
# 10. Text -  the actual review

# %%
#Data cleaning
#check for reviews other than food
#check for duplicate entries
#check for inconsistent data
df.sort_values('ProductId',axis=0,inplace=True)
clean_df = df.drop_duplicates(subset={'UserId','Score','Time','Text'},keep='first')
clean_df.shape
# Out:
# (364183, 10)

# %%
#remaining %of data
sum(clean_df['Id'].value_counts())/sum(df['Id'].value_counts())
# Out:
# 0.6926080324981838

# %%
#inconsistent data
clean_df.loc[clean_df.HelpfulnessNumerator>clean_df.HelpfulnessDenominator]
# Out:
#           Id   ProductId          UserId              ProfileName  \
# 59301  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
# 41159  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 59301                     3                       1      5  1224892800
# 41159                     3                       2      4  1212883200
#
#                                             Summary  \
# 59301             Bought This for My Son at College
# 41159  Pure cocoa taste with crunchy almonds inside
#
#                                                     Text
# 59301  My son loves spaghetti so I didn't hesitate or...
# 41159  It was almost a 'love at first bite' - the per...

# %%
#drop inconsistent data
clean_df1 = clean_df.drop(clean_df['Id'].loc[clean_df.HelpfulnessNumerator>clean_df.HelpfulnessDenominator])

# %%
#convert the Text and Summary cols into lower case
lower_summary = clean_df1.Summary.str.lower()
clean_df1['Summary'] = lower_summary
lower_text = clean_df1.Text.str.lower()
clean_df1['Text'] = lower_text

# %%
clean_df1.reset_index()
clean_df1.shape
# Out:
# (364181, 10)

# %%
import re
#removing reviews other than food like book or music
patterns=[r'\bbooks?\b','\breads?\b',r'\breading\b',r'\bpoetry\b',r'\bmusic\b',r'\bplay\b',r'\bplaying\b',r'\bmovies?\b',r'\bpoems?\b']
final=clean_df1
for pattern in tqdm(patterns):
    final=final.drop(list(final[final.Text.str.contains(pattern)].index),axis=0)
    final=final.drop(list(final[final.Summary.str.contains(pattern)].index),axis=0)
final
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=9.0), HTML(value='')))
#             Id   ProductId          UserId                ProfileName  \
# 138686  150504  0006641040   AQEYF1AXARWJZ  Les Sinclair "book maven"
# 476617  515426  141278509X   AB1A5EGHHVA9M                    CHelmic
# 22621    24751  2734888454  A1C298ITT645B6          Hugh G. Pritchard
# 22620    24750  2734888454  A13ISQV0U9GZIC                  Sandikaye
# 157850  171161  7310172001   AFXMWPNS1BLU4                 H. Sandler
# ...        ...         ...             ...                        ...
# 178145  193174  B009RSR8HO   A4P6AN2L435PV                     romarc
# 173675  188389  B009SF0TN6  A1L0GWGRK4BYPT              Bety Robinson
# 204727  221795  B009SR4OQ2  A32A6X5KCP7ARG                    sicamar
# 5259      5703  B009WSNWC4   AMP7K1O84DH1T                       ESTY
# 302474  327601  B009WVB40S  A3ME78KVX31T21                       K'la
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 138686                     1                       1      4  1212278400
# 476617                     1                       1      5  1332547200
# 22621                      0                       0      5  1195948800
# 22620                      1                       1      2  1192060800
# 157850                     0                       0      5  1229385600
# ...                      ...                     ...    ...         ...
# 178145                     0                       0      5  1350432000
# 173675                     0                       0      5  1350518400
# 204727                     1                       1      5  1350604800
# 5259                       0                       0      5  1351209600
# 302474                     0                       0      5  1351123200
#
#                                       Summary  \
# 138686                 chicken soup with rice
# 476617                     the best drink mix
# 22621                       dog lover delites
# 22620                           made in china
# 157850                       excellent treats
# ...                                       ...
# 178145                         love!!  love!!
# 173675  amazing!! great sauce for everything!
# 204727                          awesome taste
# 5259                                delicious
# 302474                                 tasty!
#
#                                                      Text
# 138686  a very entertaining rhyming story--cleaver and...
# 476617  this product by archer farms is the best drink...
# 22621   our dogs just love them.  i saw them in a pet ...
# 22620   my dogs loves this chicken but its a product f...
# 157850  i have been feeding my greyhounds these treats...
# ...                                                   ...
# 178145  love, love this sweetener!!  i use it in all m...
# 173675  you have to try this sauce to believe it! it s...
# 204727  i bought this hazelnut paste (nocciola spread)...
# 5259    purchased this product at a local store in ny ...
# 302474  i purchased this to send to my son who's away ...
#
# [355850 rows x 10 columns]

# %%
#remaining data size
sum(final['Id'].value_counts())/sum(df['Id'].value_counts())
# Out:
# 0.6767602231967959

# %%
#remove unwanted text from the reviews like instead of i've keep i have 
#replace n't, 'll, 's, 've, 're, 't, 'd, 'm
from tqdm.notebook import tqdm
def subsitute(text):
    text=re.sub(r'can\'t','can not',text)
    text=re.sub(r'won\'t','will not',text)
    
    text=re.sub(r'n\'t',' not',text)
    text=re.sub(r'\'ll',' will',text)
    text=re.sub(r'\'s',' is',text)
    text=re.sub(r'\'ve',' have',text)
    text=re.sub(r'\'re',' are',text)
    text=re.sub(r'\'t',' not',text)
    text=re.sub(r'\'d',' would',text)
    text=re.sub(r'\'m',' am',text)
    return text

# %%
#remove html tags
def removeHTML(text):
    text=re.sub(r'https?\S+','',text)
    text=re.sub(r'<.*?>','',text)
    return text

# %%
def removePunctuation(text):
    text=re.sub(r'[^A-za-z\s]','',text)#remove puntuations
    text=re.sub(r'\S*\d\S*','',text)#remove alphanumeric words
    return text

# %%
stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
#clean the text review column and store in a list
final_reviews=[]
#test=[""""newman's own" products are generally very good, with high quality ingediants and perfect execution.  this organic dark chocolate bar (54% cocoa) was perfectly sweet, without being bitter or too rich.  two of us spent an hour slowly munching through one bar, savoring every bite.<br /><br />a real treat of high quality dark chocolate.  definitely worth a try!"""]
#final.Text.values
for text in tqdm(final.Text.values):
    text= removeHTML(text)#removes html tags and attributes
    text= subsitute(text)#converts short words to normal words
    text= removePunctuation(text).strip()#removes punctuation and alphanumeric words
    text = ' '.join(ele for ele in text.split() if ele not in stopwords)
    final_reviews.append(text.strip())
final_reviews
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=355850.0), HTML(value='')))
# ['entertaining rhyming storycleaver catchythe illustrations imaginative fit right however paperback somewhat small flimsy would opt bigger edition',
#  'product archer farms best drink mix ever mix flavored packet oz water bottle contains natural sweetner stevia real fruit flavoring no food coloring colored fruit vegetable colors pure natural tastes great eight packets box contains calories per packet thank archer farms',
#  'dogs love saw pet store tag attached regarding made china satisfied safe',
#  'dogs loves chicken product china wont buying anymore hard find chicken products made usa one isnt bad good product wont take chances till know going china imports',
#  'feeding greyhounds treats years hounds little finicky love treats expensive relative biscuits find good addition diet treats easy teeth since protein treat careful not overindulge pet regular basis great treats take walks stuff pocket easily found prices vary vendor vendor shop around',
#  'one product welsh terrier eat sophie food alergies careful feed dog oscar also gets treats loves no food alergies product simple ingredients no additives dogs need',
#  'dog treat lhasa apso eat makes happ becuase no added ingredients preservatives well no added salt dog treat vet approves',
#  'liver treas phenomenal received oz bucket amazon began training month old alaskan malamute month passed knows sit stay paw speak bucket almost empty lasted month worth every penny ive read malamutes stubborn quite dogs gave poodles gobbled begging treats highly recommended plus liver cubes broken quadrants product',
#  'treat dog liked obedience training remained favorite ever since not met dog not like treat',
#  'no waste even day goes hunger strike always room one extra powder bottom makes real treat food never met pooch not go crazy treats',
#  'wanted treat accepted well liked rescue animalsthis treat healthy loved legged beings homeit not contain sugar grains silly vegetables virtually treats contain dogs cats ferrets carnivores not cattle eat grain rabbits eat vegetables whyyyy companies add sugarbeet pulp corn syrup carnivore foods dangerous cause death animal diabetesit pretty easy break smaller pieces cats kittens weak jaws wonderful use aid gain trust abused dog not cause stomach upset given common sense amountsi like goes long way costs alot heal maintain train abused rescued dogsno minus product pricei not afford use much would like',
#  'westie loves things loves anything liver one best expensive weight well worth freezedrying process concentrates flavor nutrition susie gives snouts',
#  'dog treat terrier eat crumble dry food loves',
#  'new puppy loves treat pay attention walking training one note pieces quite large cut smaller pieces recommended daily amount goes furtherall dogs dog park not resist pocket treats usually surrounded crowd dogs poking pocket',
#  'dog loves treats started using training purposes treats healthy',
#  'great treat three dogs absolutely love ordering regularly price great',
#  'buying thses vet expensive glad found online dog loves thanks',
#  'girls love cut smaller use training definately able keep dogs attention know something yummy tasty coming way price right amount long price remains perfect plan steady supply great product',
#  'oz larger find pet stores less expensive shipped day ordered arrived days later prime',
#  'one dog picky eater crumble liver treat food bowl loves dog not eat try not disappointed',
#  'golden get picky eating not priority worried training going anxious not eat training treats wellthese eat greatfull however not best smell definitely not something would eat purchasing',
#  'cut small pieces corgi pup treat actually becomes mini treats prevent throwing diet allows us give multiple treats going potty outside like mini treats time also use whenever puppy meets stranger make sure four paws ground give already learned inhibit desire jump people amazing appreciate made usa no weird chemicals worry pup loves work',
#  'yes bit expensive high quality pure nutrition good training treat not high calories highly recommend',
#  'two german shepherds use training treats also use brush not enjoy much know get treats tried every treat available best',
#  'extremely big bucket yummy treats training great value pieces large cut smaller pieces regular training purposes',
#  'liver chunks like crack dogs niblets magic training dogs critters anything although freezedried liver pricey cut chunks tiny chinks use training rewarding saying love good dog',
#  'naturaldogs favorite treat not give many constipate dog dogs anything treats',
#  'dog trainer recommended obedience class found best price amazon puppy loves treats great training treats used moderation much organ meat not good anyone also excellent put treats container nonliver treatscookies use container shaker help train dog come treats get liver flavored dust coating makes dog love even no limit liver dusted treatstwo paws stuff',
#  'three finicky dogs love product like way cut small pieces training one ingredient liver sourced within united states feel confident safe giving dogs buy regular basis priced better pet supply store seen even larger chains qualifies free shipping also nice',
#  'dog not enthusiastic food enjoys treats light weight easy carry number treats per day must limited',
#  'dogs love either straight crumbled food would otherwise not eat not get sick almost never ever reject quite often reject treats certainly treats tend always enjoy fact careful not feed not know healthy eat quantity certainly not wallet last long time though especially compare weight however dogs wolf quite quickly highly recommend reward doggies',
#  'dogs eating liver treats years also use treats training treats crude protein getting high quality treat make sure dog enough water since treats make dogs thirsty',
#  'intially introduced protreat beef liver freeze dried dog treats veterinarian office rudy jack russell terrior usually not interested dog treats responded like would never seen beforei bought couple cans pretty pricey gave sparingly tricks would protreats really entertaining rudy take meds glaucoma thank heavens found large size good value not takes medicine gives great tricks return day happy camper despite loss sight one eyerudy says best part day think cj',
#  'dogs love freeze dried liver good price size container',
#  'tried everything including cheese chicken hot dogs one eat',
#  'dog little maltese loves product knows get reward business wee wee pads works every time reinforce behavior also received product timely fashion thanks amazon',
#  'dogs love treats treats ever found situations treats fail get dog attention example treats impossible ignore incredible training aidbig bonus also simple good dog liver healthy treat supposed help combat weepy eyes unlike commercial treats one not loaded bunch junk not good dog byproducts like good ingredient dog love',
#  'dog loves natural treat price cannot beat store',
#  'great treat dogs read label dogs certain sizes many per day violated dog got upset stomach giving heads cost bit high treats get lot buy largest tub dogs go crazy',
#  'ounce protreat beef liver treats great value dog loves need reach tub sit put paw even cut tiny pieces sometimes sprinkle onto food gobbles food size last',
#  'dogs love treats freeze dried easy throw zip lock bag take wonderful training treats easy put pocket great deal',
#  'year old black lab favorite treats best training dog anything get one treats even month old black lab puppy goes running kennel tell go bed knows liver treat coming way since sliced small large container last complaint dog loves much knows shes getting one starts drool not drooler gotta toss one quick',
#  'airedale loves taste beef freeze dried dog treats use training really works',
#  'dog loves treats great quality cheaper buying big box stores really not go wrong',
#  'dogs love treats last long time light easy give dogs amazon best price treats always house',
#  'not beat natural treats dogs love align well raw diet great value ordering amazon sell local pet store',
#  'great product chihuahuas favorite treat never problems except bucket runs fast',
#  'great deal compared small bags treats available pet store importantly dog adores use extra special treat usually goes crate soon notices one hand runs crate waits tail wagging downside liver cubes smell horrible humans anyway leave powdery residue behind reviews noted powder great sprinkling dry food finicky dog',
#  'treats similar purebites however since small dogs peke mix generally not give snacks suited medium large dogs small dogs large mouths smaller dogs hard time biting possibility choking pieces large dense small mouths break smaller pieces give doggies purebites hand flatter easier chew snacks appear made way larger dogs would give either snack purebites',
#  'dogs favorite treats ordered three containers site advertised would receive fourth container free three containers came timely fashion dog happy never get fourth container dog pretty disappointed',
#  'used protreat beef liver freeze dried dog treats several years lb hound favorite treat great use training fairly expensive treat used properly lasts quite would definitely recommend',
#  'great product dogs love treat hard get eat time however product pure protein therefore not great kidneys eat many limit treats per day',
#  'dogs favorite treat pass treats dried beef liver love fact low fat healthy',
#  'product get petsmart much better price service quick efficient use old wiener dog iron deficiencies helped alot not vet',
#  'ordered thought bit pricey decided give try anyway glad dogs absolutely love dried liver treats since dogs small cut treats half still large enough pieces satisfy great training definitely order would recommend anyone',
#  'otter happy product happy come across dealer line best deal respect cost convenience',
#  'happy product shipping thanks always like business amazon',
#  'little dog loves treats besides rewarding dog crash treats mix medicine works great',
#  'wonderful treat labs love healthy natural small cubes great hiding toys great mental challenge dogs figure get treats work animal field every dog come across gobbles little cubes go long way',
#  'gimborn liver treats far dogs favorite treat wonderful training reward good quality beware dog sniff wherever hidden pockets',
#  'freeze dried treats dogs favorite treats spending double price paid local area pet stores ie chuck petsmart arrived promptly well packaged highly recommended',
#  'every pup ever owned loved treats anything like brand tried another refused eat love pups treat like childrenbuy thesemine not spolied diva tiffany get every holiday never without supply hand try greenies',
#  'delicious treat dogs unhappy withamazon paid product never received itnanci shea',
#  'dog would anything treats looked around brandsbut best',
#  'great price better stores around dogs love not mind taking pills',
#  'not much puppy not try one ofthe freeze dried liver treats gave one another springer spanielwe met beach see races sometimesa long distance great get another treat greattraining aid',
#  'use training treat working two dogs dogs getting bored ol treats even though tried give wide variety one far favorite like natural no preservatives pieces pretty big easily broken finger nail carry around pocket like working watch neighborhood dogs wanting treat price quite good also definitly worth try',
#  'know people suggested product not training could not disagree en english bulldog solely motivated able teach voice commands short time liver treats rewards peices could bit smaller often cut bit healthy treats love bulldog loves',
#  'promy dogs maltese poodle mix go crazy treats obedient know holding treats handsince freeze dried not worry treats drying outalthough comes big cubes able cut cubes smaller pieces plastic knife order lengthen usage stash dog treatsmy containers always came little crumbspowder container bottomconnot uniform sizesnot cheapconclusion still great product need modificationssince every morsel appears flavorful dogs need pinkie nail size amount reward themit may seem like crumbspowder useless actually still somewhat useful used powder coat bland chewy dog treats dog food toys etc',
#  'excellent productmy dog loves thingsturns nose every thing elsei would much recommend product dogs big plusthere made usa',
#  'time spent waiting order fly traps arrive went bought regular fly ribbon bad fly problem not sure kind flies slightly bigger fruit flies least week one fly traps caught zero flies fly trap caught probably flies regular fly ribbon one point even saw fly fly trap thought caught gone even pictures prove',
#  'even cheap ribbon traps caught many dozens flies days liquid bait traps rescue victor fly magnet caught hundreds days thing remains empty best seems rescue trap call stinker reeks works trap space traps hundreds flies not work indoor trap directions say used outdoors protected weather',
#  'well purchased inexpensive figured shipping might well two different areas small apartment hours nothing managed kill flies swatting',
#  'something supposed attract flys could not cared less months time caught maybe flies sure miniscule fraction kitchen waste money',
#  'bought local hardware store terrible fly problem trapped one fly year still hanging still one flydo not buy product',
#  'bought apartment infested fruit flies hours trap quotattractedquot many flies within days practically gone may not long term solution flies driving crazy consider buying one caution surface sticky try avoid touching',
#  'ineffective worthless bought product indoors two outdoor fly traps outdoor traps worked immediately noticed less flies home backdoor past week however indoor trap caught zero flies yet one week outdoor traps caught combined get excited looking trap thinking fly caught realize picture fly instead not waste money product',
#  'well received item placed area put fly paper beforewe far fewer victims regular fly paper looks like not really catch big ones like fly paper however price decent looks attractive regular strip fly paper',
#  'flies buzz around thing like not even many flies around would think luck fly would least bounced stuck pure luck not single fly caught still flies annoyingly buzzing around area not catch single fruit fly house fly horse fly mosquito even hungry spider ant cardboard box worth nickel sprayed sticky stuff company laughing bank chicago illinois',
#  'product not work hang kitchen days no fly attractedit not worth time money return please buyer beware strongly suggest go find item',
#  'let put way flies stay traps left looks like safe island flies',
#  'please not waste money fly trap absolutely useless bought two product kitchen always bbq go pool fly get house started make jokes product not one fly far gone since hang weeks ago terrible product',
#  'used traditional fly rolls past dubious hubby opened box showed little standalone cardboard fly trap desperate though fullon gnat invasion kitchen put places counter settling one near coffee pot gnats seemed love gather first seemed ignore next days finding way onto trap one point gave countingthere dozens product great ridding pesky gnats love poisonfree stand countertop want tall ceilings would make hanging strip less useful wishing hang little hanger included well not make claim larger flies not catch thosethere none around think would better choices outdoors product little fly trap job asked not beat',
#  'nurturing plant work well decided repot larger pot must gotten funky soil soon repotted overrun large colony small flies swatting getting bug guts hand frequently stopped bothering gross exclamations fact city san francisco compost aggravated situationi bought one nitfy traps set plant voila instead hands getting daily dose bug guts trap lined tiny suckers months trap pretty much covered gross part need order another one not sure well work larger inserts works really well tiny annoying flies',
#  'thing item trapped fruit flies not work fly trap would not recommend',
#  'happy item many flies disturbing kitchen put product near window works fantastically',
#  'many flies house product weeks stuck fly thus far',
#  'wish would read reviews making purchase basically cardsotck box sticky outside pinkish things look like entrances trap pictures no inside trap flies stuck outside basically fly paper horribly horribly horribly overpriceddo favor get fly paper fly strips yuck factor much cheaper',
#  'worst product gotten long time would rate no star could simply not catch single fly bug sort went hardware store bought oldfashioned spiral fly paper effective unuasual influx flys house fall needed something',
#  'placed around house several days setup fly attracting trap vicinity literally watched flies avoid trap days excited see one lilbugger land surface disappointed approached examine flew away paper tacky pressure human finger applied small flies hardly trap',
#  'could rate fly trap lower one star would think flies come miles away come laugh thing would success taking flies vat scalding water getting fly randomly run box ridiculousnesswaste',
rote hill concern food presented choking risk received ridiculous uncaring response possibly imagine first felt compelled tell particular formula designed maintain oral care different formula adult cats completely insulting much aware fact intentionally purchased food stated oral care benefits addition fact formulas nothing concern particular formula next asked transitioned cat new food interpret lame attempt trying make feel somehow responsible situation short putting food blender would no appropriate way transitioning one pet avoid risk choking producti not one minute believe cat experience isolated occurence thinking buying product please please please aware risk real',
#  'although may seem tad precious vet recommended young cat not brush clean teeth fresh breath hope teeth life plus girl friend love taste',
#  'several cats one vomiting problem many years tried many cats food science diet sensitive one foods works otherss purina sensitive also great royal canin oral sensitive think science diet purina best also give cat prednisolone vet prescription vet said inflamatory bowel disease',
#  'fed siberian husky food since old enough eat solid food still eats fine beautiful condition',
#  'month old labradoodle loves food prior trying food tried several brands times raja ate food threw little later even science diet brands tried variations like lamb rice formula not like would rather stay hungry eat food something original formulaone note make sure keep food sealed box cool dry place per instructions',
#  'definitely not buy amazon price tag dog loves buy supermarket mere stars amazon price stars tried multiple brands flavors far favorite always give little whatever eat addition eat plain unlike brands like pedigree refuse eat science diet almost good likes better cheaper great meal pour half cup chicken beef stalk friend life',
#  'nine cats crazy kibbles last thing want lbs cat food cats hate buying',
#  'looking lid fit sizes oz cat food cans brands grain blue buffalo wilderness slightly oversized oz cans compared fancy feast wellness lids seen pet store elsewhere fit smaller cans not slightly larger ones anyway petmate lids fit size oz cans along two sizes larger cans however plastic stiff hard next impossible snap basically unusable threw awayi also ordered another brand lids ourpets small cans dream fit sizes small cans soft easy put take would recommend petmate kittykaps sure',
#  'really best cat dog food cover buy inexpensive well good tight fit sizes get couple hard find pet stores',
#  'use three different sizes cat food cans kitty loves variety lids fit also care sort thing cute design ears helpful pulling wish could find closer live would not pay dollars shipping every time lost one',
#  'absolutely best cat food cover ever run across fits common sizes including smaller cans seal well last long time another review said difficult get true first couple uses give little use become easier snap great product',
#  ...]

# %%
#clean the summary column and store in a list
final_summary=[]
#test=[""""newman's own" products are generally very good, with high quality ingediants and perfect execution.  this organic dark chocolate bar (54% cocoa) was perfectly sweet, without being bitter or too rich.  two of us spent an hour slowly munching through one bar, savoring every bite.<br /><br />a real treat of high quality dark chocolate.  definitely worth a try!"""]
#final.Text.values
for text in tqdm(final.Summary.values):
    text= removeHTML(text)#removes html tags and attributes
    text= subsitute(text)#converts short words to normal words
    text= removePunctuation(text).strip()#removes punctuation and alphanumeric words
    text = ' '.join(ele for ele in text.split() if ele not in stopwords)
    final_summary.append(text.strip())
final_summary
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=355850.0), HTML(value='')))
# ['chicken soup rice',
#  'best drink mix',
#  'dog lover delites',
#  'made china',
#  'excellent treats',
#  'sophie treats',
#  'best healthy dog treat',
#  'alaskan malamute loves',
#  'best treat ever',
#  'year old maltese always loved',
#  'dogs cats ferrets love',
#  'snouts',
#  'best dog treat ever',
#  'great puppy training',
#  'great',
#  'terrific treats',
#  'dog loves',
#  'happy dog',
#  'perfect small dogs',
#  'good product slow super saver shipping',
#  'dog treats',
#  'great product dogs',
#  'not buy used',
#  'dogs love best treat rewards training',
#  'great product',
#  'amazing training treat',
#  'best dog treat great training dogs love',
#  'dog favorite treat',
#  'careful dogs love',
#  'pro treat dried dog treats',
#  'great treat',
#  'crack dogs',
#  'good stuff',
#  'great product great deal',
#  'great diabetic dog',
#  'good',
#  'dogs love',
#  'fast shipment',
#  'dogs love',
#  'golden loves',
#  'corgi cocaine',
#  'healthy high quality dog treat',
#  'save best training',
#  'great product value',
#  'best dog treats',
#  'dogs love',
#  'livr licious',
#  'excellent product made usa',
#  'liver treats',
#  'dogs love',
#  'favorite',
#  'protreat beef liver freeze dried best part rudy day',
#  'best',
#  'treat dog eat',
#  'dog loves',
#  'like candy dog',
#  'wonderful treat great price',
#  'great treats dogs',
#  'dog loves',
#  'liver treats',
#  'best dog treats',
#  'dog lover',
#  'great training treats',
#  'great',
#  'puppy loves',
#  'awesome',
#  'good quality',
#  'dog would anything treat',
#  'great product',
#  'great reward dog',
#  'rolls royce dog treats',
#  'great treat',
#  'sammy loves',
#  'dogs loveem',
#  'training rewardhigh protein nongreasy',
#  'freeze dried liver dog treats',
#  'great training',
#  'not resist',
#  'dogs go nuts liver treats',
#  'perfect treat dog training good price',
#  'great treat use high value reward',
#  'great liver treatsextra benefits white dogs',
#  'good stuff',
#  'no black tears',
#  'good natural treats',
#  'trainng tool',
#  'pro treat indeed',
#  'natural dogs love',
#  'like dog heroin nothing dog not liver treats',
#  'great expensive',
#  'great treats dog loves',
#  'great dog treats',
#  'dog loved',
#  'dogs love',
#  'delicious pure treats',
#  'gimborn liver bits treats',
#  'canine crack',
#  'dog treats beef liver',
#  'excellent product',
#  'dog loves',
#  'dog loves never tires',
#  'dogs love plus healthy',
#  'excellent service',
#  'love faucet',
#  'dogs love',
#  'no waste dogs love liver treats great training',
#  'treat dog eat',
#  'dog loves',
#  'pure puppy addiction',
#  'dogs favorite treat',
#  'great dog training',
#  'dog loves',
#  'dogs go crazy',
#  'great treats training',
#  'cut pieces smaller',
#  'protreat freeze dried beef liver',
#  'best treats tried far',
#  'great treats',
#  'dogs love',
#  'really good treats training',
#  'review freeze dried liver treats dogs',
#  'not go wrong',
#  'stewart protreats',
#  'best',
#  'chihuahuas favorite',
#  'love least dog',
#  'great treat probably not small dogs',
#  'good treats somewhat falsely advertised',
#  'lucky favorite',
#  'dogs love',
#  'dogs abby zoe favorite treat',
#  'good service excellent price',
#  'dogs crazy',
#  'best snack item dog',
#  'dog treat',
#  'gimborn protreat liver',
#  'puff',
#  'gimborn liver treats',
#  'unbelievable price',
#  'fantastic',
#  'delicous treat dogs',
#  'healthy dog treats',
#  'great treat',
#  'dog treats',
#  'really great treats',
#  'one best treats dogs',
#  'expensive worth',
#  'best treat market',
#  'dogs love pieces not sized uniformly melt wet',
#  'jah',
#  'great treat',
#  'two paws',
#  'best dog',
#  'no mess dogs love',
#  'freeze dried liver treats',
#  'no shipping charges december drfostersmithcom',
#  'loves liver treats',
#  'not get much better',
#  'dog treats',
#  'excellent',
#  'dogs love stuff',
#  'great treat expensive',
#  'woof woof',
#  'pro treat',
#  'sbould get crums',
#  'delicious mildly sweet cookie',
#  'terrific treats',
#  'ripoff',
#  'not catch fruit flies',
#  'epic fail worst fly trap ever created',
#  'great product',
#  'not work',
#  'still waiting catch fly',
#  'regular fly ribbon worked way better',
#  'not work different types traps one empty',
#  'not yet',
#  'cold not care less',
#  'caught fly',
#  'sure death flies',
#  'worthless indoor trap',
#  'prettier fly paper',
#  'complete waste money',
#  'not work',
#  'read reviews ordered',
#  'waste money',
#  'works great',
#  'gross effective',
#  'not work',
#  'item excellent kill insects',
#  'many flies house product weeks stuck fly thus far',
#  'big rip',
#  'not work not waste money',
#  'not work',
#  'day zero flies',
#  'get something else',
#  'fly trap not trap much',
#  'junk',
#  'utterly worthless',
#  'one fruitfly stuck',
#  'complete waste money',
#  'not sticky situation',
#  'thirty bucks',
#  'flies begone',
#  'great product',
#  'wow make islickers',
#  'developed crush johnny depp',
#  'beetlejuice',
#  'underrated showcase scaryzany burtonland',
#  'aging classic',
#  'another twisted masterpiece burton',
#  'bettlejuicebettlejuicebettlejuice',
#  'inexpensive arrived timely manner',
#  'great experience',
#  'beetlejuice greatmovie cheated dvd',
#  'tim burton classic',
#  'awesome remastered version',
#  'bluray review',
#  'clarification',
#  'burton true debut',
#  'fabulous comedic fanasy directed master',
#  'quoti ghost babequot',
#  'research beatlejuice video french version',
#  'certificate puerile',
#  'modern day fairy tale',
#  'tim burton fantasy world alive',
#  'freaky silly wry creative',
#  'soundtrack cd sampler comes bluray edition',
#  'always pleasure',
#  'beetlejuice beetlejuice beatlejuice',
#  'beetlejuice',
#  'best tim burton film stick format',
#  'timely delivery no complaints',
#  'adventuresome comedic entertainment',
#  'beetlejuice',
#  'macabre fun whole family',
#  'beetlejuice',
#  'funny love',
#  'tim burton film dvd',
#  'america critic',
#  'sweet',
#  'research',
#  'subtitles',
#  'good solution mole problem',
#  'not work',
#  'could not believe worked',
#  'bust',
#  'worthless',
#  'not buy',
#  'powerfull',
#  'poor design',
#  'still moles',
#  'works placement',
#  'not work',
#  'get moles',
#  'great product',
#  'mole stopper',
#  'meets expectations',
#  'not work',
#  'works',
#  'victor mole trap',
#  'wow work',
#  'works great',
#  'like ones dad used',
#  'works well',
#  'study use great',
#  'kills moles',
#  'worked',
#  'waste time',
#  'no bees',
#  'not order product',
#  'solution yellow jacket problem',
#  'welcome mat no takers',
#  'poor quality control',
#  'best kind',
#  'poor quality control',
#  'slays yellow jackets salmon',
#  'gopher hunter',
#  'waste money not work',
#  'thing works',
#  'gopher traps',
#  'work great',
#  'victor gopher trap review',
#  'hmmwe catch one',
#  'killer',
#  '',
#  'update caught one first try',
#  'works',
#  'gopher trap',
#  'excellent trap',
#  'trigger not sensitive waste money',
#  'wish would tried sooner',
#  'works well actually easy set',
#  'end gopher problems',
#  'yep kills golphers',
#  'easy set',
#  'woodstream gopher trap',
#  'better gopher repelling devices',
#  'junky gopher trap',
#  'moley moley',
#  'simply best',
#  'one works',
#  'caught mole',
#  'best mole trap ever used',
#  'difficult set',
#  'finally trap works',
#  'great trap',
#  'work bring use',
#  'finally something really works',
#  'trap works not follow directions',
#  'trap found worked',
#  'awesome must',
#  'moles safe piece junk',
#  'mole eliminator',
#  'work one traps major dangerous manufacturing flaw',
#  'good trap requires strong hands',
#  'works',
#  'best mole trap found',
#  'caught one',
#  'caught days',
#  'caught first mole within hours setting trap',
#  'best way kill moles like traps must set correctly',
#  'trap works',
#  'hard cock never misses longtime favorite works',
#  'no luck yet',
#  'moles no',
#  'works',
#  'reviews said',
#  'best mole trap ever',
#  'great mole getter',
#  'effective',
#  'worked',
#  'caught mole minutes',
#  'heavy duty really works well',
#  'actually worked',
#  'caught one first night mole super highway',
#  'works perfectly usage advice found',
#  'darn things work',
#  'mole traps outstanding product',
#  'mole traps',
#  'extremely hard set',
#  'victor mole trap',
#  'dissatisfied',
#  'not work hard set maybe',
#  'not buy trap',
#  'good luck',
#  'total lack response northern tool equipment',
#  'not work sandy soil',
#  'question usage',
#  'thanks',
#  'not work',
#  'not get set',
#  'mole trap',
#  'use grub insect killer instead',
#  'woodstream mole trap',
#  'victor mole traps',
#  'mole trap',
#  'solution works',
#  'victor mole trap review',
#  'hard catch',
#  'mole elimination',
#  'mole trap',
#  'worked',
#  'trap need simply awesome',
#  'problem setting',
#  'ordered items one defective',
#  'mole dead',
#  'works',
#  'no moles',
#  'best trap moles',
#  'really works',
#  'victor outosight mole traps',
#  'mole trap',
#  'works',
#  'works',
#  'death moles',
#  'awesome trap',
#  'worksit really really works',
#  'great trap',
#  'took worked',
#  'beginner luck',
#  'moles yard buy',
#  'feel strongly ways',
#  'defective device',
#  'great mole trap',
#  'bought',
#  'worked first try',
#  'best mole trap needed little tweaking',
#  'best trap available',
#  'done',
#  'not easy set hard use',
#  'finally solution mole problem',
#  'moleinator insta kill',
#  'kill bugs yard first',
#  'mole trp',
#  'perfect product',
#  'worked',
#  'caught first mole yesterday',
#  'happy hunter dfw',
#  'mole killer worked',
#  'great product',
#  'caught mole within hours',
#  'set way others say works great',
#  'works',
#  'even caveman could',
#  'victor mole trap',
#  'not useful ca',
#  'broke saw first use',
#  'looking forward using',
#  'bye bye mole',
#  'not waste time products methods',
#  'works',
#  'works',
#  'woo hoo something finally works',
#  'works',
#  'really works',
#  'great trap',
#  'difficult set use',
#  'moles',
#  'not follow directions',
#  'mole terminator',
#  'really works',
#  'best answer found moles',
#  'effective practice setting',
#  'disappointed unbowed',
#  'impossible assemble',
#  'success victor trap',
#  'mole trap works',
#  'finally way get rid moles',
#  'sight trap',
#  'victor site',
#  'sight mole trap',
#  'worked',
#  'first mole hours',
#  'best mole trap',
#  'victor works well mole trapping tedious',
#  'victor mole traps sight',
#  'works works fast',
#  'mole trap victor',
#  'mole trap',
#  'victor mole trap fantastic',
#  'yup worked',
#  'trap best style trap used',
#  'worked well',
#  'caught none',
#  'dangerous not work',
#  'scissor mole trap way kill mole',
#  'excellent mole trap',
#  'worked perfectly',
#  'works great',
#  'one little booger god knows many left',
#  'simple effective durable trap',
#  'great item',
#  'worked well us',
#  'works terrific',
#  'inexpensive nontoxic works',
#  'really work',
#  'flea trap refill pads',
#  'really works',
#  'not work well without light',
#  'work great concert measures',
#  'better expected',
#  'flea trap paper',
#  'worked great',
#  'long time user',
#  'victor ultimate flea trap refills',
#  'works great',
#  'flea trap works',
#  'victor flea trap',
#  'sticky paper works great',
#  'victor flea trap',
#  'works sort',
#  'fewer columbolla mites w flea traps',
#  'not work maybe not enough fleas',
#  'last desperate act',
#  'really works',
#  'flea traps great',
#  'good product',
#  'things work',
#  'would rate no stars could',
#  'completely useless',
#  'catches fleas',
#  'work perfect',
#  'good news bad news',
#  'not working',
#  'flea problem',
#  'works',
#  'victor flea trap superb',
#  'job',
#  'really good product',
#  'use money kindling fireplace instead',
#  'victor ultimate flea trap refills pack',
#  'simple works',
#  'worried first',
#  'helpful product',
#  'helps keep control sorts bugs',
#  'sticky flea trap disks',
#  'works great',
#  'vsteinmetz',
#  'waste',
#  'sticky effective',
#  'flea trap',
#  'mother',
#  'victor flea trap',
#  'never',
#  'pads glued',
#  'works terrific',
#  'not work',
#  'not argue says',
#  'nope',
#  'not waste money',
#  'gonna need',
#  'not bother',
#  'buy',
#  'chance',
#  'victor ultimate flea trap',
#  'flea control',
#  'flea trap traps',
#  'almost perfect',
#  'works great',
#  'thank god tried',
#  'flea trap',
#  'job flea trap sheetsdisks hard peel',
#  'great sounding idea not effective',
#  'not buy',
#  'okay',
#  'product kicks serious butt',
#  'must',
#  'absolute rubbish',
#  'flea stuck',
#  'works',
#  'best non toxic fix',
#  'works bought refills',
#  'refill',
#  'worked expected',
#  'great product',
#  'excellent product without chemicals',
#  'good product',
#  'useless',
#  'useless',
#  'works well',
#  'not pictured',
#  'works great',
#  'excellent product',
#  'never seen anything like',
#  'lid plastic wall thread weak hold bottle',
#  'flies',
#  'inclined post great result',
#  'beyond reasonable expectation',
#  'works takes days flies show',
#  'fly magnet',
#  'full flys great thanks amazon',
#  'great',
#  'really works',
#  'excellent',
#  'effective',
#  'bye bye flies',
#  'never seen anything like',
#  'amazing gross',
#  'awesome fly killet',
#  'best fly traps ever',
#  'humiliation disgust',
#  'stinky trap',
#  'not attract cluster flies',
#  'high hopesbut not work',
#  'victor',
#  'extremely effective',
#  'nice design poor performance',
#  'not worth effort smell',
#  'stinky',
#  'stinky',
#  'great',
#  'works wonders',
#  'says',
#  'really works',
#  'product works',
#  'waste money',
#  'not work',
#  'broken hook not catch flies',
#  'fragile breaks easy fly comes breaks',
#  'get trap',
#  'flimsy size go bigger',
#  'not work',
#  'excellent',
#  'far good',
#  'simply amazing',
#  'works better expected',
#  'cheeapp',
#  'place flies not think',
#  'review fly trap',
#  'not work',
#  'great product',
#  'fantastic fly trap',
#  'cheap plastic difficult lid',
#  'trap amazing',
#  'works flies flock trap',
#  'works',
#  'watch smell',
#  'fly trap works',
#  'chamber doom',
#  'lots dead flies',
#  'aokay',
#  'poor fly trap',
#  'best fly trap ever',
#  'supposed',
#  'great fly traps',
#  'flies gone',
#  'works great',
#  'amazing',
#  'amazing smells win radius downwind soooo effective',
#  'fly trap magic',
#  'incredible',
#  'works blew away',
#  'takes begins work',
#  'useless cluster flies',
#  'not work',
#  'great fly catcher',
#  'stinky',
#  'not work poor design',
#  'total crap',
#  'great fly trap',
#  'great trap',
#  'perfect size bigger might better',
#  'extremely effective',
#  'horrible',
#  'not organic natural despite search organic food coloring',
#  'pleasantly surprised',
#  'love colors',
#  'happy',
#  'true red white blue',
#  'easy use',
#  'no mess',
#  'small condensed color',
#  'great color',
#  'great food color',
#  'stunning',
#  'gel food coloring kit',
#  'needs wilton',
#  'make martha stewart style cakes cookies',
#  'beautiful food color gel',
#  'bold vivid colors',
#  'great colors',
#  'good product value would buy',
#  'never buy another',
#  'great gel colors excellent lids',
#  'rainbow food',
#  'no better wilton',
#  'love great colors',
#  'nice bright colors',
#  'love set',
#  'colors',
#  'great colors',
#  'food coloring made easy',
#  'great colors fast delivery',
#  'food coloring made easy',
#  'nice colors',
#  'wonderful product gives professional results',
#  'work treat',
#  'happy',
#  'great',
#  'must',
#  'not experienced baking job',
#  'great stuff',
#  'lovely colors',
#  'dying',
#  'ateco color food coloring kit',
#  'great set',
#  'great colors',
#  'ateco food coloring',
#  'good color mixes easily',
#  'great color',
#  'suitable lab use not perfect',
#  'food dye present',
#  'beautiful vibrant colors',
#  'ateco food coloring',
#  'exp date',
#  'amazing colors',
#  'nice colors',
#  'fabulous',
#  'product fabulous',
#  'great basic color kit',
#  'nice color need quite bit',
#  'pleased last years',
#  'need info',
#  'recommended',
#  'true colors great frosting',
#  'not expected',
#  'beautiful true colors',
#  'food coloring',
#  'wonderful',
#  'food coloring',
#  'dyeing ateco food coloring',
#  'right',
#  'dentist recommends product',
#  'not fan',
#  'mint gum',
#  'must every home',
#  'effective tasty',
#  'great tasting excellent relieving coughchest congestion',
#  'breathe easy',
#  'works wonders',
#  'wonderful sore mouth sore throat',
#  'try like',
#  'excellent source good health',
#  'breathe easy',
#  'favorite flavor',
#  'great asthma reliever',
#  'not breathe without',
#  'delicious',
#  'learning exhale',
#  'mainstay anyone breathing allergy issues',
#  'herbal remedy bronchial distress',
#  'good product',
#  'great product difficult purchase summer',
#  'not great',
#  'love bars',
#  'favorite protein bar',
#  'love',
#  'love genisoy bars',
#  'great tasting protein bar',
#  'could become addict',
#  'excellent',
#  'great snack',
#  'goodbye old friend',
#  'amazing',
#  'chocolatey taste texture',
#  'good',
#  'yum yum',
#  'melts mouth',
#  'better expected',
#  'described freezedried icecream',
#  'perfect gift',
#  'delicious',
#  'yummy fun',
#  'great job',
#  'astranaut icecream scores',
#  'tastes like always',
#  'good need order',
#  'world treat',
#  'astronaut ice cream',
#  'gift recipient loved',
#  'great birthday treat',
#  'delicious',
#  'pack freeze dried goodness',
#  'omnomnomnomnomnom',
#  'great taste convenient sweet',
#  'freeze dried ice cream plain simple',
#  'love em',
#  'yummy',
#  'astronaut ice cream addict',
#  'astronaut ice cream',
#  'great',
#  'astronaut ice cream',
#  'kids love em',
#  'space ice cream',
#  'good quality',
#  'good price great value',
#  'fun gift soldiers',
#  'great',
#  'great deal',
#  'melts mouth',
#  'shattered hopes',
#  'not happy customer',
#  'arrived smashed pieces',
#  'guilty pleasure',
#  'love',
#  'best ever',
#  'excellent service',
#  'best candy ever',
#  'exactly expected',
#  'awesome light weigh snack',
#  'yummy came great condition',
#  'long time favorite',
#  'breakfast champs great present',
#  'buyer beware',
#  'warning not advertised',
#  'disappointed',
#  'awesome',
#  'loved',
#  'loved astronaut ice cream sandwich',
#  'great handpresso',
#  'lateoutdated months late',
#  'excellent pods used briel espresso unit years',
#  'like starbuck espresso pods better',
#  'better starbucks espresso pods',
#  'loves convenience ga',
#  'almost expired sept',
#  'incredible quality',
#  'little piece heaven',
#  'date months',
#  'shipment expired years',
#  'expressions decaf pods',
#  'great easy cup espresso',
#  'outstanding flavor great price',
#  'great pod great price',
#  'delicious',
#  'best bang buck',
#  'easy tummies',
#  'dog version catnip',
#  'good joint supplement',
#  'works great',
#  'excellent product',
#  'beware tested burns like fire',
#  'ark ear cleanser',
#  'stuff awesome bottle sucks',
#  'great stuff',
#  'best ear cleaner dogs',
#  'excellent alternative conventional medicine side effects',
#  'great money',
#  'waste no wine',
#  'simple effective amazon purchase',
#  'wine saver set stoppers',
#  'oh no price went',
#  'love',
#  'must',
#  'true wine saver',
#  'great wine storage good price',
#  'item',
#  'great product recommend',
#  'great concept low quality jam permanently',
#  'way go guys',
#  'terrific',
#  'vacu vin',
#  'works better expected',
#  'satisfied',
#  'love love love',
#  'gr invention',
#  'works',
#  'works great',
#  'easier use standard vacu vin',
#  'works well',
#  'wish came case',
#  'good product great customer service',
#  'best',
#  'far superior regular lower priced vacu vin piece',
#  'small easy works',
#  'yes works',
#  'sucked air right',
#  'great product',
#  'wine saver',
#  'vacuum nature not abhor',
#  'no click',
#  'easier old version',
#  'easier use standard vacu vin',
#  'happy',
#  'nice product',
#  'easy use',
#  'works great',
#  'great product easy use',
#  'good product',
#  'must',
#  'great product',
#  'no click sound',
#  'love thing',
#  'good product made better',
#  'really works',
#  'extremely successful scam',
#  'wine saver',
#  'supposed',
#  'simplicity best',
#  'wine saver',
#  'failed',
#  'older model reliable',
#  'vacu vin wine saver',
#  'money saver',
#  'great product saves money',
#  'love item great party gift',
#  'great wino tool',
#  'best thing world',
#  'vacuvin winesavers musthave',
#  'like',
#  'wine',
#  'performs advertised',
#  'no complaints',
#  'great wine sealer',
#  'best herbal tea digestion',
#  'good effective product',
#  'best cleansing tea ever',
#  'nice little garlic baker',
#  'garlic lover',
#  'rocklingranny',
#  'fine sugarless gum peppermint burst',
#  'met expectations not norm',
#  'trident white gum',
#  'yummy everything',
#  'fine product warned',
#  'superb',
#  'no actual picture container',
#  'deeeeelishis',
#  'best frosting ever',
#  'overpriced not needed',
#  'bad taste',
#  'think taste mouth beholder',
#  'wilton frosting',
#  'not good taste',
#  'better buying making different icing',
#  'secretly switched coffee favorite restaurant garbage',
#  'yay finally',
#  'pirouline rolled chocolate hazelnut rolled wafers',
#  'product excellent seller not much',
#  'pirouline rolled wafers chocolate hazelnut',
#  'cvb fan gem',
#  'boxed evolution',
#  'great albumtoo bad cant buy amazon',
#  'favorite american band',
#  'easy fun productno dirty fingers',
#  'five barks yip yaps',
#  'great price shipping',
#  'best treats ever',
#  'jack love yip yap',
#  'dog hates',
#  'yipyaps',
#  'important dog loved',
#  'high hopes',
#  'dog favorite treat',
#  'yip yap smells like cp',
#  'anergen',
#  'cat not touch',
#  'deters cat overeating',
#  'allergenic dog food',
#  'good dog',
#  'great',
#  'prolonging quality life',
#  'given gift life',
#  'cats not wrong',
#  'two cats really enjoy au jus cans',
#  'no crazy additives',
#  'great cat toy',
#  'tiny cheaply made cat choked',
#  'work wonders',
#  'great toy teeth flosser dogs',
#  'best dental protection dogs',
#  'premium quality dog food',
#  'good stuff',
#  'filler food empty leaves cat always needing',
#  'great food cats',
#  'great product trust vet not hype',
#  'research',
#  'obeseoverweight cat research',
#  'food give cats',
#  'best catfood',
#  'works great cat',
#  'great cat food great value',
#  'cat food',
#  'thank god found food',
#  'not live without cat food',
#  'thing cats eat',
#  'mostly cleared vomiting problem',
#  'cat loves cat food',
#  'thing worked',
#  'molly likes',
#  'excellent cat food',
#  'love hills',
#  'great pukey cat',
#  'stops fecal balls',
#  'worth money',
#  'helps cat teeth',
#  'sickening filler ingredients high price',
#  'science diet terrible cats addictive',
#  'great product',
#  'bag keeps getting smaller price stays',
#  'best dental health',
#  'huge difference',
#  'bought fiber',
#  'blotto cries',
#  'cat likes taste',
#  'worst snaplock reseal ever made',
#  'look ingredient list',
#  'worst junk food ever',
#  'saved kitty dental surgery',
#  'terrible ingredients cat eat',
#  'please avoid',
#  'excellent cat food',
#  'toasted corn rice cats',
#  'cat food',
#  'wow cant believe expensive bag corn',
#  'kitty seems love',
#  'claims',
#  'kitty loves',
#  'food cats agree',
#  'cat food buy',
#  'hills science diet oral care',
#  'wish would started using years ago',
#  'best cat food ever',
#  'saved cat',
#  'yummi cats',
#  'meow',
#  'good food',
#  'excellent good health cat',
#  'please avoid',
#  'buyer beware potential choking hazard',
#  'best thing cat teeth',
#  'vomiting cats',
#  'hill science diet dry puppy food',
#  'puppy loves',
#  'dog loves',
#  'cats love',
#  'good idea bad execution',
#  'kitty kap best lid available',
#  'works great',
#  'terrific cat food cover',
#  ...]

# %%
#generate random reviews to check
for i in range(10):
    r=np.random.randint(0,356001)
    print(final.Text.iloc[r])
    print('='*100)
# Out:
# the pacific chai vanilla latte (decaffeinated) is so good. i like it in the evening as it does not disturb my sleep. it is a great alternative to coffee, hot chocolate or regular tea and the taste is wonderful.
# ====================================================================================================
# i add this cherry berry and one of the other fruit packages to my tea each morning.  delicious and healthy.
# ====================================================================================================
# this is good instant decaf coffee!!!  it smells good, it looks good, and the flavor is better than most cups of regular coffee served in restaurants.  that's my opinion and i'm stickin' to it.
# ====================================================================================================
# i really enjoy african coffees and particularly the ethiopian varieties. the medium roast was probable appropriate for this bean, but the roasting was very inconsistent which gave it a green coffee bean flavor.  it was reasonalby priced but not worth buying.
# ====================================================================================================
now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
snbstemmer = SnowballStemmer("english")
wnl = WordNetLemmatizer()

# %%
summary_stem=[]
for ele in final_summary:
    words = ele.split()
    summary_stem.append(' '.join([snbstemmer.stem(word) for word in words]))

# %%
summary_stem[0:10]
# Out:
# ['chicken soup rice',
#  'best drink mix',
#  'dog lover delit',
#  'made china',
#  'excel treat',
#  'sophi treat',
#  'best healthi dog treat',
#  'alaskan malamut love',
#  'best treat ever',
#  'year old maltes alway love']

# %%
summary_lemma=[]
for ele in final_summary:
    words = ele.split()
    summary_lemma.append(' '.join([wnl.lemmatize(word) for word in words]))

# %%
summary_lemma[0:10]
# Out:
# ['chicken soup rice',
#  'best drink mix',
#  'dog lover delites',
#  'made china',
#  'excellent treat',
#  'sophie treat',
#  'best healthy dog treat',
#  'alaskan malamute love',
#  'best treat ever',
#  'year old maltese always loved']

# %%
text_stem=[]
for ele in final_reviews:
    words = ele.split()
    text_stem.append(' '.join([snbstemmer.stem(word) for word in words]))

# %%
text_lemma=[]
for ele in final_reviews:
    words = ele.split()
    text_lemma.append(' '.join([wnl.lemmatize(word) for word in words]))

# %%
text_stem[0:10]
# Out:
# ['entertain rhyme storycleav catchyth illustr imagin fit right howev paperback somewhat small flimsi would opt bigger edit',
#  'product archer farm best drink mix ever mix flavor packet oz water bottl contain natur sweetner stevia real fruit flavor no food color color fruit veget color pure natur tast great eight packet box contain calori per packet thank archer farm',
#  'dog love saw pet store tag attach regard made china satisfi safe',
#  'dog love chicken product china wont buy anymor hard find chicken product made usa one isnt bad good product wont take chanc till know go china import',
#  'feed greyhound treat year hound littl finicki love treat expens relat biscuit find good addit diet treat easi teeth sinc protein treat care not overindulg pet regular basi great treat take walk stuff pocket easili found price vari vendor vendor shop around',
#  'one product welsh terrier eat sophi food alergi care feed dog oscar also get treat love no food alergi product simpl ingredi no addit dog need',
#  'dog treat lhasa apso eat make happ becuas no ad ingredi preserv well no ad salt dog treat vet approv',
#  'liver trea phenomen receiv oz bucket amazon began train month old alaskan malamut month pass know sit stay paw speak bucket almost empti last month worth everi penni ive read malamut stubborn quit dog gave poodl gobbl beg treat high recommend plus liver cube broken quadrant product',
#  'treat dog like obedi train remain favorit ever sinc not met dog not like treat',
#  'no wast even day goe hunger strike alway room one extra powder bottom make real treat food never met pooch not go crazi treat']

# %%
type(text_stem)
# Out:
# list

# %%
text_lemma[0:10]
# Out:
# ['entertaining rhyming storycleaver catchythe illustration imaginative fit right however paperback somewhat small flimsy would opt bigger edition',
#  'product archer farm best drink mix ever mix flavored packet oz water bottle contains natural sweetner stevia real fruit flavoring no food coloring colored fruit vegetable color pure natural taste great eight packet box contains calorie per packet thank archer farm',
#  'dog love saw pet store tag attached regarding made china satisfied safe',
#  'dog love chicken product china wont buying anymore hard find chicken product made usa one isnt bad good product wont take chance till know going china import',
#  'feeding greyhound treat year hound little finicky love treat expensive relative biscuit find good addition diet treat easy teeth since protein treat careful not overindulge pet regular basis great treat take walk stuff pocket easily found price vary vendor vendor shop around',
#  'one product welsh terrier eat sophie food alergies careful feed dog oscar also get treat love no food alergies product simple ingredient no additive dog need',
#  'dog treat lhasa apso eat make happ becuase no added ingredient preservative well no added salt dog treat vet approves',
#  'liver treas phenomenal received oz bucket amazon began training month old alaskan malamute month passed know sit stay paw speak bucket almost empty lasted month worth every penny ive read malamute stubborn quite dog gave poodle gobbled begging treat highly recommended plus liver cube broken quadrant product',
#  'treat dog liked obedience training remained favorite ever since not met dog not like treat',
#  'no waste even day go hunger strike always room one extra powder bottom make real treat food never met pooch not go crazy treat']

# %%
#now we have reduced the words into their stem/lemma forms
#using this we can create BoW, TF-IDF or W2Vec to actually convert the words into numbers\
#which we can use then for training classification algorithms.
#we will go with stemming
bow_summary = CountVectorizer(ngram_range=(1,2),min_df=10,max_features=5000)
summary_final_bow_vec = bow_summary.fit_transform(summary_stem)
bow_text = CountVectorizer(ngram_range=(1,2),min_df=10,max_features=5000)
text_final_bow_vec = bow_text.fit_transform(text_stem)

# %%
bow_summary.get_feature_names()[:100] #viewing 100 features of summary out of 5000
# Out:
# ['abl',
#  'absolut',
#  'absolut amaz',
#  'absolut best',
#  'absolut delici',
#  'absolut fantast',
#  'absolut favorit',
#  'absolut love',
#  'absolut wonder',
#  'acai',
#  'accept',
#  'accord',
#  'accur',
#  'acid',
#  'acid coffe',
#  'acquir',
#  'acquir tast',
#  'activ',
#  'actual',
#  'actual tast',
#  'actual work',
#  'ad',
#  'ad sugar',
#  'add',
#  'addict',
#  'addit',
#  'ador',
#  'adult',
#  'adventur',
#  'advertis',
#  'aerat',
#  'aerogarden',
#  'afford',
#  'african',
#  'afternoon',
#  'aftertast',
#  'agav',
#  'agav nectar',
#  'age',
#  'ago',
#  'agre',
#  'ah',
#  'ahmad',
#  'ai',
#  'ai not',
#  'aid',
#  'air',
#  'al',
#  'alcohol',
#  'ale',
#  'alert',
#  'aliv',
#  'allerg',
#  'allergen',
#  'allergi',
#  'allnatur',
#  'allpurpos',
#  'alltim',
#  'alltim favorit',
#  'almond',
#  'almond butter',
#  'almond flour',
#  'almost',
#  'almost good',
#  'almost like',
#  'almost perfect',
#  'alo',
#  'alon',
#  'alot',
#  'alreadi',
#  'alright',
#  'also',
#  'altern',
#  'altern coffe',
#  'altern regular',
#  'altern soda',
#  'altern sugar',
#  'although',
#  'altoid',
#  'alway',
#  'alway good',
#  'alway great',
#  'amaz',
#  'amaz coffe',
#  'amaz delici',
#  'amaz flavor',
#  'amaz good',
#  'amaz price',
#  'amaz product',
#  'amaz stuff',
#  'amaz tast',
#  'amaz tea',
#  'amazon',
#  'amazon not',
#  'amazon price',
#  'amazoncom',
#  'ambrosia',
#  'america',
#  'american',
#  'ami']

# %%
bow_text.get_feature_names()[4900:] #viewing 100 features of reviews
# Out:
# ['work well',
#  'work wonder',
#  'workout',
#  'world',
#  'worm',
#  'worri',
#  'wors',
#  'worst',
#  'worth',
#  'worth everi',
#  'worth extra',
#  'worth money',
#  'worth price',
#  'worth tri',
#  'would',
#  'would also',
#  'would better',
#  'would buy',
#  'would definit',
#  'would eat',
#  'would expect',
#  'would find',
#  'would get',
#  'would give',
#  'would given',
#  'would go',
#  'would good',
#  'would great',
#  'would help',
#  'would high',
#  'would like',
#  'would love',
#  'would make',
#  'would never',
#  'would nice',
#  'would not',
#  'would order',
#  'would pay',
#  'would prefer',
#  'would probabl',
#  'would purchas',
#  'would rate',
#  'would rather',
#  'would recommend',
#  'would say',
#  'would still',
#  'would suggest',
#  'would take',
#  'would tast',
#  'would think',
#  'would tri',
#  'would use',
#  'would want',
#  'would work',
#  'wow',
#  'wrap',
#  'wrapper',
#  'write',
#  'write review',
#  'written',
#  'wrong',
#  'wrote',
#  'xylitol',
#  'yard',
#  'yeah',
#  'year',
#  'year ago',
#  'year love',
#  'year not',
#  'year old',
#  'year tri',
#  'year use',
#  'yearold',
#  'yeast',
#  'yellow',
#  'yes',
#  'yesterday',
#  'yet',
#  'yet not',
#  'yield',
#  'yogi',
#  'yogurt',
#  'york',
#  'yorki',
#  'young',
#  'younger',
#  'yr',
#  'yr old',
#  'yrs',
#  'yuck',
#  'yum',
#  'yum yum',
#  'yummi',
#  'zero',
#  'zero calori',
#  'zevia',
#  'zico',
#  'zing',
#  'zip',
#  'ziplock']

# %%
tfidf_summary = TfidfVectorizer(ngram_range=(1,2),min_df=10,max_features=5000)
summary_tfidf= tfidf_summary.fit_transform(final_summary)
tfidf_text = TfidfVectorizer(ngram_range=(1,2),min_df=10,max_features=5000,lowercase=False)
text_tfidf = tfidf_text.fit_transform(text_stem)

# %%
tfidf_summary.get_feature_names()#top 100 features of summary using tfidf
# Out:
# ['able',
#  'absolute',
#  'absolute best',
#  'absolute favorite',
#  'absolutely',
#  'absolutely amazing',
#  'absolutely best',
#  'absolutely delicious',
#  'absolutely love',
#  'absolutely wonderful',
#  'acai',
#  'acceptable',
#  'accurate',
#  'acid',
#  'acid coffee',
#  'acidic',
#  'acquired',
#  'acquired taste',
#  'active',
#  'actual',
#  'actually',
#  'actually tastes',
#  'ad',
#  'add',
#  'added',
#  'added sugar',
#  'addict',
#  'addicted',
#  'addicting',
#  'addiction',
#  'addictive',
#  'adding',
#  'addition',
#  'additive',
#  'additives',
#  'adds',
#  'adorable',
#  'adore',
#  'adult',
#  'adults',
#  'advertised',
#  'advertisement',
#  'advertising',
#  'aerator',
#  'aerogarden',
#  'affordable',
#  'african',
#  'afternoon',
#  'aftertaste',
#  'agave',
#  'agave nectar',
#  'ages',
#  'ago',
#  'agree',
#  'ah',
#  'ahmad',
#  'ai',
#  'ai not',
#  'aid',
#  'air',
#  'al',
#  'alcohol',
#  'ale',
#  'alert',
#  'alive',
#  'allergen',
#  'allergic',
#  'allergies',
#  'allergy',
#  'allnatural',
#  'allpurpose',
#  'alltime',
#  'alltime favorite',
#  'almond',
#  'almond butter',
#  'almond flour',
#  'almonds',
#  'almost',
#  'almost good',
#  'almost like',
#  'almost perfect',
#  'aloe',
#  'alone',
#  'alot',
#  'already',
#  'alright',
#  'also',
#  'alternative',
#  'alternative coffee',
#  'alternative regular',
#  'alternative soda',
#  'alternatives',
#  'although',
#  'altoids',
#  'always',
#  'always good',
#  'always great',
#  'amazed',
#  'amazing',
#  'amazing coffee',
#  'amazing flavor',
#  'amazing price',
#  'amazing product',
#  'amazing stuff',
#  'amazing taste',
#  'amazing tea',
#  'amazingly',
#  'amazingly delicious',
#  'amazingly good',
#  'amazon',
#  'amazon price',
#  'amazoncom',
#  'ambrosia',
#  'america',
#  'american',
#  'amish',
#  'among',
#  'amount',
#  'amy',
#  'anchovies',
#  'angel',
#  'animal',
#  'animals',
#  'anise',
#  'annie',
#  'another',
#  'another good',
#  'another great',
#  'another winner',
#  'answer',
#  'antioxidant',
#  'antioxidants',
#  'ants',
#  'anymore',
#  'anyone',
#  'anything',
#  'anything else',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'apart',
#  'apparently',
#  'appears',
#  'apple',
#  'apple cider',
#  'apple juice',
#  'apples',
#  'applesauce',
#  'approve',
#  'approved',
#  'apricot',
#  'apricots',
#  'arizona',
#  'aroma',
#  'aroma taste',
#  'aromatic',
#  'around',
#  'arrival',
#  'arrived',
#  'arrived broken',
#  'arrowhead',
#  'arsenic',
#  'artificial',
#  'artificial flavor',
#  'artificial sweetener',
#  'artificial sweeteners',
#  'asian',
#  'ask',
#  'aspartame',
#  'ass',
#  'assorted',
#  'assortment',
#  'ate',
#  'attention',
#  'attractive',
#  'authentic',
#  'auto',
#  'automatic',
#  'available',
#  'average',
#  'avoid',
#  'aware',
#  'away',
#  'aweful',
#  'awesome',
#  'awesome coffee',
#  'awesome cookies',
#  'awesome deal',
#  'awesome flavor',
#  'awesome price',
#  'awesome product',
#  'awesome snack',
#  'awesome stuff',
#  'awesome taste',
#  'awesome tea',
#  'awesomeness',
#  'awful',
#  'awful taste',
#  'awsome',
#  'babies',
#  'babies love',
#  'baby',
#  'baby food',
#  'baby formula',
#  'baby likes',
#  'baby loves',
#  'back',
#  'back memories',
#  'back nature',
#  'bacon',
#  'bad',
#  'bad aftertaste',
#  'bad bad',
#  'bad batch',
#  'bad coffee',
#  'bad not',
#  'bad packaging',
#  'bad price',
#  'bad product',
#  'bad shipping',
#  'bad taste',
#  'badly',
#  'bag',
#  'bagel',
#  'bagels',
#  'bagged',
#  'bags',
#  'bags pack',
#  'bait',
#  'bait switch',
#  'bake',
#  'baked',
#  'baked beans',
#  'baked oatmeal',
#  'baker',
#  'bakery',
#  'baking',
#  'baking mix',
#  'balance',
#  'balanced',
#  'ball',
#  'balls',
#  'balsamic',
#  'balsamic vinegar',
#  'bamboo',
#  'banana',
#  'banana nut',
#  'bananas',
#  'bang',
#  'bang buck',
#  'bar',
#  'bar ever',
#  'bar none',
#  'barbecue',
#  'barely',
#  'bargain',
#  'barley',
#  'baronet',
#  'barry',
#  'bars',
#  'bars ever',
#  'base',
#  'based',
#  'basic',
#  'basil',
#  'basket',
#  'basmati',
#  'basmati rice',
#  'batch',
#  'batter',
#  'bay',
#  'bay coffee',
#  'bbq',
#  'bbq sauce',
#  'beach',
#  'bean',
#  'bean coffee',
#  'bean direct',
#  'beans',
#  'beans ever',
#  'bear',
#  'bears',
#  'beat',
#  'beat price',
#  'beats',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'become',
#  'bed',
#  'bedtime',
#  'bee',
#  'beef',
#  'beef jerky',
#  'beer',
#  'belgian',
#  'believe',
#  'believer',
#  'bell',
#  'belly',
#  'belly flops',
#  'benecol',
#  'benefit',
#  'benefits',
#  'bergamot',
#  'berries',
#  'berry',
#  'best',
#  'best almond',
#  'best around',
#  'best baby',
#  'best bar',
#  'best bbq',
#  'best beef',
#  'best best',
#  'best black',
#  'best brand',
#  'best bread',
#  'best breakfast',
#  'best brown',
#  'best brownies',
#  'best buy',
#  'best candy',
#  'best canned',
#  'best cat',
#  'best cereal',
#  'best chai',
#  'best chicken',
#  'best chili',
#  'best chips',
#  'best chocolate',
#  'best choice',
#  'best cinnamon',
#  'best cocoa',
#  'best coconut',
#  'best coffee',
#  'best cookie',
#  'best cookies',
#  'best crackers',
#  'best cup',
#  'best dark',
#  'best deal',
#  'best decaf',
#  'best dog',
#  'best dried',
#  'best drink',
#  'best dry',
#  'best earl',
#  'best energy',
#  'best espresso',
#  'best ever',
#  'best far',
#  'best flavor',
#  'best flavored',
#  'best food',
#  'best formula',
#  'best found',
#  'best friend',
#  'best fruit',
#  'best gf',
#  'best ginger',
#  'best gluten',
#  'best glutenfree',
#  'best granola',
#  'best green',
#  'best gum',
#  'best gummi',
#  'best gummy',
#  'best healthy',
#  'best honey',
#  'best hot',
#  'best ice',
#  'best iced',
#  'best instant',
#  'best jerky',
#  'best kcup',
#  'best licorice',
#  'best low',
#  'best marinade',
#  'best market',
#  'best mint',
#  'best mints',
#  'best mix',
#  'best mustard',
#  'best natural',
#  'best no',
#  'best oatmeal',
#  'best olive',
#  'best one',
#  'best organic',
#  'best pancake',
#  'best pancakes',
#  'best pasta',
#  'best peanut',
#  'best pizza',
#  'best popcorn',
#  'best pretzels',
#  'best price',
#  'best product',
#  'best protein',
#  'best quality',
#  'best ramen',
#  'best rice',
#  'best salad',
#  'best salsa',
#  'best salt',
#  'best sauce',
#  'best seasoning',
#  'best snack',
#  'best soda',
#  'best soup',
#  'best soy',
#  'best stevia',
#  'best stuff',
#  'best sugar',
#  'best taste',
#  'best tasting',
#  'best tea',
#  'best thing',
#  'best tomato',
#  'best treat',
#  'best treats',
#  'best tried',
#  'best tuna',
#  'best value',
#  'best vanilla',
#  'best waffle',
#  'best water',
#  'best way',
#  'best white',
#  'best whole',
#  'best yet',
#  'bet',
#  'better',
#  'better coffee',
#  'better expected',
#  'better milk',
#  'better peanut',
#  'better price',
#  'better regular',
#  'better starbucks',
#  'better sugar',
#  'better tasting',
#  'better thought',
#  'betty',
#  'betty crocker',
#  'beverage',
#  'beware',
#  'beware not',
#  'beyond',
#  'big',
#  'big bag',
#  'big disappointment',
#  'big dogs',
#  'big easy',
#  'big fan',
#  'big hit',
#  'big train',
#  'bigelow',
#  'bigger',
#  'bird',
#  'birds',
#  'birthday',
#  'birthday gift',
#  'biscotti',
#  'biscuit',
#  'biscuits',
#  'bisquick',
#  'bit',
#  'bit pricey',
#  'bit sweet',
#  'bite',
#  'bites',
#  'bits',
#  'bitter',
#  'bitter aftertaste',
#  'bitter taste',
#  'bitterness',
#  'bitters',
#  'black',
#  'black beans',
#  'black cherry',
#  'black licorice',
#  'black tea',
#  'black tiger',
#  'blackberry',
#  'blah',
#  'bland',
#  'blast',
#  'blast past',
#  'blech',
#  'bleh',
#  'blend',
#  'blend coffee',
#  'blends',
#  'bliss',
#  'blood',
#  'blood sugar',
#  'bloody',
#  'bloody mary',
#  'blue',
#  'blue agave',
#  'blue buffalo',
#  'blue dog',
#  'blueberries',
#  'blueberry',
#  'bob',
#  'bob red',
#  'bodied',
#  'body',
#  'bold',
#  'bold coffee',
#  'bold flavor',
#  'bold not',
#  'bold taste',
#  'bomb',
#  'bone',
#  'bones',
#  'bonsai',
#  'bonsai tree',
#  'boost',
#  'booster',
#  'boot',
#  'booty',
#  'boring',
#  'boston',
#  'bother',
#  'bottle',
#  'bottled',
#  'bottled water',
#  'bottles',
#  'bottom',
#  'bought',
#  'bouillon',
#  'bouquet',
#  'bowl',
#  'bowls',
#  'box',
#  'boxed',
#  'boxes',
#  'boxes pack',
#  'boy',
#  'boys',
#  'bpa',
#  'bpa free',
#  'bran',
#  'brand',
#  'brands',
#  'brazil',
#  'bread',
#  'bread ever',
#  'bread machine',
#  'bread mix',
#  'breadsticks',
#  'break',
#  'breakfast',
#  'breakfast blend',
#  'breakfast cereal',
#  'breakfast food',
#  'breakfast tea',
#  'breast',
#  'breath',
#  'breed',
#  'brew',
#  'brewed',
#  'brewer',
#  'brewers',
#  'brewing',
#  'bright',
#  'brilliant',
#  'bring',
#  'bring back',
#  'brings',
#  'brings back',
#  'british',
#  'brittle',
#  'broccoli',
#  'broke',
#  'broken',
#  'brooklyn',
#  'broth',
#  'brought',
#  'brown',
#  'brown rice',
#  'brown sugar',
#  'brownie',
#  'brownie mix',
#  'brownies',
#  'bubble',
#  'bubble gum',
#  'buck',
#  'bucks',
#  'buckwheat',
#  'buddy',
#  'budget',
#  'buds',
#  'buffalo',
#  'bug',
#  'bugs',
#  'bulk',
#  'bull',
#  'bulldog',
#  'bully',
#  'bully sticks',
#  'bunch',
#  'bunnies',
#  'bunny',
#  'burger',
#  'burgers',
#  'burn',
#  'burned',
#  'burnt',
#  'burst',
#  'business',
#  'busy',
#  'butter',
#  'butter ever',
#  'butter toffee',
#  'buttermilk',
#  'butterscotch',
#  'buttery',
#  'buy',
#  'buy amazon',
#  'buy bulk',
#  'buy product',
#  'buyer',
#  'buyer beware',
#  'buying',
#  'bye',
#  'cabinet',
#  'cacao',
#  'cadbury',
#  'cafe',
#  'caffe',
#  'caffeinated',
#  'caffeine',
#  'caffeine free',
#  'cajun',
#  'cake',
#  'cake mix',
#  'cakes',
#  'cal',
#  'california',
#  'call',
#  'called',
#  'calm',
#  'calming',
#  'calorie',
#  'calorie snack',
#  'calories',
#  'came',
#  'campbell',
#  'camping',
#  'canada',
#  'cancer',
#  'candies',
#  'candy',
#  'candy bar',
#  'candy bars',
#  'candy ever',
#  'cane',
#  'canidae',
#  'canin',
#  'canine',
#  'canned',
#  'canned cat',
#  'canned food',
#  'canned tuna',
#  'cannot',
#  'cans',
#  'cans dented',
#  'cant',
#  'cappuccino',
#  'capsules',
#  'caramel',
#  'caramels',
#  'carb',
#  'carb pasta',
#  'carb snack',
#  'carbonated',
#  'carbs',
#  'cardboard',
#  'care',
#  'careful',
#  'carefully',
#  'caribou',
#  'carmel',
#  'carnation',
#  'carousel',
#  'carrot',
#  'carry',
#  'case',
#  'cashew',
#  'cashews',
#  'cat',
#  'cat eat',
#  'cat favorite',
#  'cat food',
#  'cat likes',
#  'cat litter',
#  'cat love',
#  'cat loves',
#  'cat not',
#  'cat treat',
#  'cat treats',
#  'catch',
#  'catfood',
#  'catnip',
#  'cats',
#  'cats eat',
#  'cats favorite',
#  'cats go',
#  'cats like',
#  'cats love',
#  'cats loved',
#  'cats not',
#  'caught',
#  'cause',
#  'caused',
#  'causes',
#  'caution',
#  'caviar',
#  'celestial',
#  'celestial seasonings',
#  'celiac',
#  'celiacs',
#  'celtic',
#  'celtic sea',
#  'cents',
#  'cereal',
#  'cereal ever',
#  'cereal great',
#  'cereals',
#  'certainly',
#  'certified',
#  'certified organic',
#  'cet',
#  'ceylon',
#  'chai',
#  'chai ever',
#  'chai latte',
#  'chai tea',
#  'chamomile',
#  'chamomile tea',
#  'chance',
#  'change',
#  'change pace',
#  'changed',
#  'changed formula',
#  'changed recipe',
#  'changes',
#  'charge',
#  'charm',
#  'chaser',
#  'cheap',
#  'cheaper',
#  'cheaper elsewhere',
#  'cheaper local',
#  'cheaper store',
#  'cheapest',
#  'check',
#  'cheddar',
#  'cheerios',
#  'cheese',
#  'cheesecake',
#  'cheesy',
#  'cheetos',
#  'cheezit',
#  'chef',
#  'chemical',
#  'chemical taste',
#  'chemicals',
#  'cherries',
#  'cherry',
#  'chestnuts',
#  'chew',
#  'chew toy',
#  'chewer',
#  'chewers',
#  'chewing',
#  'chewing gum',
#  'chews',
#  'chewy',
#  'chex',
#  'chia',
#  'chia seeds',
#  'chicken',
#  'chicken broth',
#  'chicken noodle',
#  'chicken soup',
#  'chicory',
#  'chihuahua',
#  'child',
#  'childhood',
#  'childhood favorite',
#  'childhood memories',
#  'children',
#  'chile',
#  'chili',
#  'chili powder',
#  'chili sauce',
#  'china',
#  'chinese',
#  'chip',
#  'chip cookie',
#  'chip cookies',
#  'chipotle',
#  'chips',
#  'chips ever',
#  'chips great',
#  'choc',
#  'chocolate',
#  'chocolate bar',
#  'chocolate bars',
#  'chocolate cake',
#  'chocolate chip',
#  'chocolate chips',
#  'chocolate coffee',
#  'chocolate covered',
#  'chocolate ever',
#  'chocolate flavor',
#  'chocolate heaven',
#  'chocolate lover',
#  'chocolate lovers',
#  'chocolate milk',
#  'chocolate not',
#  'chocolate taste',
#  'chocolates',
#  'chocolatey',
#  'chocolaty',
#  'choice',
#  'choices',
#  'choking',
#  'choking hazard',
#  'cholesterol',
#  'choose',
#  'chow',
#  'chowder',
#  'christmas',
#  'christmas gift',
#  'chunk',
#  'chunks',
#  'chunky',
#  'chutney',
#  'cider',
#  'cinnamon',
#  'citric',
#  'citric acid',
#  'citrus',
#  'city',
#  'claims',
#  'clam',
#  'clam chowder',
#  'class',
#  'classic',
#  'clean',
#  'cleaner',
#  'cleaning',
#  'clear',
#  'click',
#  'close',
#  'close real',
#  'closest',
#  'closest thing',
#  'club',
#  'clusters',
#  'co',
#  'coat',
#  'coating',
#  'coca',
#  'cocktail',
#  'coco',
#  'cocoa',
#  'cocoa mix',
#  'cocoa powder',
#  'coconut',
#  'coconut juice',
#  'coconut milk',
#  'coconut oil',
#  'coconut water',
#  'coffe',
#  'coffee',
#  'coffee bean',
#  'coffee beans',
#  'coffee best',
#  'coffee candy',
#  'coffee drink',
#  'coffee drinker',
#  'coffee drinkers',
#  'coffee ever',
#  'coffee excellent',
#  'coffee flavor',
#  'coffee good',
#  'coffee great',
#  'coffee kcups',
#  'coffee keurig',
#  'coffee like',
#  'coffee lover',
#  'coffee lovers',
#  'coffee maker',
#  'coffee not',
#  'coffee people',
#  'coffee pod',
#  'coffee pods',
#  'coffee price',
#  'coffee review',
#  'coffee shop',
#  'coffee substitute',
#  'coffee taste',
#  'coffee tea',
#  'coffee world',
#  'coffees',
#  'coke',
#  'cola',
#  'cold',
#  'collection',
#  'college',
#  'colombian',
#  'color',
#  'coloring',
#  'colors',
#  'columbian',
#  'combination',
#  'combo',
#  'come',
#  'comes',
#  'comfort',
#  'comfort food',
#  'coming',
#  'comment',
#  'commercial',
#  'community',
#  'community coffee',
#  'company',
#  'comparable',
#  'compare',
#  'compared',
#  'compares',
#  'comparison',
#  'complaints',
#  'complete',
#  'completely',
#  'complex',
#  'concentrate',
#  'concentrated',
#  'concept',
#  'condiment',
#  'condition',
#  'conditioner',
#  'confused',
#  'consider',
#  'consistency',
#  'consistent',
#  'consistently',
#  'constipation',
#  'consumer',
#  'consumption',
#  'contain',
#  'container',
#  'containers',
#  'contains',
#  'content',
#  'contents',
#  'control',
#  'convenience',
#  'convenient',
#  'convenient packaging',
#  'convenient tasty',
#  'convert',
#  'cook',
#  'cooked',
#  'cookie',
#  'cookie ever',
#  'cookie mix',
#  'cookies',
#  'cookies ever',
#  'cooking',
#  'cooks',
#  'cool',
#  'core',
#  'corn',
#  'corn flakes',
#  'corn syrup',
#  'cornbread',
#  'correct',
#  'correctly',
#  'cost',
#  'costa',
#  'costco',
#  'costly',
#  'costs',
#  'cotton',
#  'cotton candy',
#  'cough',
#  'could',
#  'could better',
#  'could find',
#  'could give',
#  'could not',
#  'could use',
#  ...]

# %%
tfidf_text.get_feature_names()#top 100 features of text using tfidf
# Out:
# ['abil',
#  'abl',
#  'abl buy',
#  'abl eat',
#  'abl find',
#  'abl get',
#  'abl order',
#  'abl purchas',
#  'absolut',
#  'absolut best',
#  'absolut delici',
#  'absolut favorit',
#  'absolut love',
#  'absolut no',
#  'absorb',
#  'acai',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'accompani',
#  'accord',
#  'account',
#  'accur',
#  'accustom',
#  'acid',
#  'acquir',
#  'acquir tast',
#  'across',
#  'act',
#  'activ',
#  'actual',
#  'actual like',
#  'actual tast',
#  'ad',
#  'ad bonus',
#  'ad littl',
#  'ad sugar',
#  'add',
#  'add bit',
#  'add extra',
#  'add flavor',
#  'add littl',
#  'add milk',
#  'add sugar',
#  'add water',
#  'addict',
#  'addit',
#  'address',
#  'adequ',
#  'adjust',
#  'admit',
#  'adopt',
#  'ador',
#  'adult',
#  'advantag',
#  'advertis',
#  'advic',
#  'advis',
#  'affect',
#  'afford',
#  'afraid',
#  'afternoon',
#  'aftertast',
#  'aftertast not',
#  'afterward',
#  'agav',
#  'agav nectar',
#  'age',
#  'ago',
#  'agre',
#  'agre review',
#  'ahead',
#  'ahoy',
#  'aid',
#  'air',
#  'airtight',
#  'al',
#  'ala',
#  'alcohol',
#  'ale',
#  'alert',
#  'allerg',
#  'allergi',
#  'allnatur',
#  'allow',
#  'almond',
#  'almond butter',
#  'almond milk',
#  'almost',
#  'almost everi',
#  'almost like',
#  'almost no',
#  'almost year',
#  'alo',
#  'alon',
#  'along',
#  'alot',
#  'alreadi',
#  'also',
#  'also add',
#  'also contain',
#  'also enjoy',
#  'also good',
#  'also great',
#  'also help',
#  'also like',
#  'also love',
#  'also made',
#  'also make',
#  'also not',
#  'also realli',
#  'also tast',
#  'also tri',
#  'also use',
#  'alter',
#  'altern',
#  'although',
#  'although not',
#  'altoid',
#  'aluminum',
#  'alway',
#  'alway fresh',
#  'alway get',
#  'alway like',
#  'alway look',
#  'alway love',
#  'alway use',
#  'amaz',
#  'amazon',
#  'amazon best',
#  'amazon carri',
#  'amazon found',
#  'amazon get',
#  'amazon good',
#  'amazon great',
#  'amazon make',
#  'amazon not',
#  'amazon offer',
#  'amazon order',
#  'amazon price',
#  'amazon prime',
#  'amazon sell',
#  'amazon ship',
#  'amazon subscrib',
#  'amazon would',
#  'amazoncom',
#  'america',
#  'american',
#  'ami',
#  'among',
#  'amount',
#  'amount sweet',
#  'anchovi',
#  'andor',
#  'angel',
#  'anim',
#  'anni',
#  'annoy',
#  'anoth',
#  'anoth brand',
#  'anoth one',
#  'anoth review',
#  'answer',
#  'anticip',
#  'antioxid',
#  'anybodi',
#  'anymor',
#  'anyon',
#  'anyon like',
#  'anyon look',
#  'anyon want',
#  'anyth',
#  'anyth els',
#  'anyth like',
#  'anytim',
#  'anyway',
#  'anywher',
#  'anywher els',
#  'apart',
#  'appar',
#  'appeal',
#  'appear',
#  'appet',
#  'appetit',
#  'appl',
#  'appl cider',
#  'appl juic',
#  'applesauc',
#  'appli',
#  'applic',
#  'appreci',
#  'approach',
#  'appropri',
#  'approv',
#  'approxim',
#  'apricot',
#  'area',
#  'arm',
#  'aroma',
#  'aromat',
#  'around',
#  'around hous',
#  'arriv',
#  'arriv perfect',
#  'arriv prompt',
#  'arriv quick',
#  'arriv time',
#  'articl',
#  'artifici',
#  'artifici color',
#  'artifici flavor',
#  'artifici sweeten',
#  'asian',
#  'asid',
#  'ask',
#  'aspartam',
#  'aspect',
#  'associ',
#  'assort',
#  'assum',
#  'assur',
#  'ate',
#  'attach',
#  'attack',
#  'attempt',
#  'attent',
#  'attract',
#  'aunt',
#  'authent',
#  'auto',
#  'automat',
#  'avail',
#  'avail amazon',
#  'avail local',
#  'averag',
#  'avid',
#  'avoid',
#  'aw',
#  'awak',
#  'awar',
#  'away',
#  'away not',
#  'awesom',
#  'awhil',
#  'babi',
#  'babi food',
#  'babi love',
#  'back',
#  'backpack',
#  'bacon',
#  'bad',
#  'bad batch',
#  'bad not',
#  'bad review',
#  'bad tast',
#  'bad thing',
#  'bag',
#  'bag last',
#  'bag make',
#  'bag not',
#  'bag one',
#  'bag open',
#  'bag tea',
#  'bagel',
#  'bake',
#  'bake good',
#  'baker',
#  'bakeri',
#  'balanc',
#  'ball',
#  'balsam',
#  'banana',
#  'bang',
#  'bar',
#  'bar not',
#  'bar tast',
#  'barbecu',
#  'bare',
#  'bargain',
#  'bark',
#  'barley',
#  'barri',
#  'base',
#  'base review',
#  'basi',
#  'basic',
#  'basil',
#  'basket',
#  'batch',
#  'bath',
#  'bathroom',
#  'batter',
#  'bay',
#  'bbq',
#  'bbq sauc',
#  'bc',
#  'beach',
#  'bean',
#  'bean not',
#  'bear',
#  'beat',
#  'beat price',
#  'beauti',
#  'becam',
#  'becom',
#  'bed',
#  'bedtim',
#  'bee',
#  'beef',
#  'beef jerki',
#  'beer',
#  'beet',
#  'beg',
#  'began',
#  'begin',
#  'behind',
#  'believ',
#  'bell',
#  'belli',
#  'bene',
#  'benefici',
#  'benefit',
#  'bergamot',
#  'berri',
#  'berri flavor',
#  'besid',
#  'best',
#  'best chocol',
#  'best coffe',
#  'best deal',
#  'best ever',
#  'best flavor',
#  'best found',
#  'best not',
#  'best one',
#  'best part',
#  'best price',
#  'best product',
#  'best tast',
#  'best tea',
#  'best thing',
#  'best tri',
#  'best use',
#  'best way',
#  'bet',
#  'better',
#  'better buy',
#  'better deal',
#  'better flavor',
#  'better not',
#  'better one',
#  'better price',
#  'better qualiti',
#  'better regular',
#  'better tast',
#  'betti',
#  'betti crocker',
#  'beverag',
#  'bewar',
#  'beyond',
#  'big',
#  'big bag',
#  'big box',
#  'big deal',
#  'big fan',
#  'big hit',
#  'bigelow',
#  'bigger',
#  'biggest',
#  'bill',
#  'bird',
#  'birthday',
#  'biscotti',
#  'biscuit',
#  'bit',
#  'bit expens',
#  'bit like',
#  'bit pricey',
#  'bit sweet',
#  'bite',
#  'bitter',
#  'bitter aftertast',
#  'bitter not',
#  'bitter tast',
#  'black',
#  'black bean',
#  'black cherri',
#  'black licoric',
#  'black pepper',
#  'black tea',
#  'blackberri',
#  'blame',
#  'bland',
#  'blend',
#  'blend coffe',
#  'blend not',
#  'blender',
#  'bless',
#  'bloat',
#  'block',
#  'blood',
#  'blood pressur',
#  'blood sugar',
#  'bloom',
#  'blow',
#  'blue',
#  'blue buffalo',
#  'blueberri',
#  'board',
#  'bob',
#  'bob red',
#  'bodi',
#  'boil',
#  'boil water',
#  'bold',
#  'bold coffe',
#  'bold flavor',
#  'bone',
#  'bonsai',
#  'bonus',
#  'boost',
#  'boot',
#  'border',
#  'bore',
#  'born',
#  'bother',
#  'bottl',
#  'bottl not',
#  'bottl water',
#  'bottom',
#  'bottom line',
#  'bought',
#  'bought amazon',
#  'bought bag',
#  'bought box',
#  'bought case',
#  'bought local',
#  'bought one',
#  'bought pack',
#  'bought product',
#  'bought two',
#  'bouillon',
#  'bowel',
#  'bowl',
#  'box',
#  'box contain',
#  'box not',
#  'boy',
#  'boyfriend',
#  'bpa',
#  'brain',
#  'bran',
#  'brand',
#  'brand coffe',
#  'brand flavor',
#  'brand like',
#  'brand not',
#  'brand one',
#  'brand tri',
#  'bread',
#  'bread machin',
#  'bread mix',
#  'break',
#  'breakfast',
#  'breakfast blend',
#  'breakfast cereal',
#  'breakfast tea',
#  'breast',
#  'breath',
#  'breed',
#  'brew',
#  'brew coffe',
#  'brew cup',
#  'brew tea',
#  'brewer',
#  'brick',
#  'bright',
#  'bring',
#  'bring back',
#  'british',
#  'brittl',
#  'broccoli',
#  'broke',
#  'broken',
#  'broth',
#  'brother',
#  'brought',
#  'brought back',
#  'brown',
#  'brown rice',
#  'brown sugar',
#  'browni',
#  'brush',
#  'btw',
#  'bubbl',
#  'buck',
#  'buckwheat',
#  'bud',
#  'buddi',
#  'budget',
#  'buffalo',
#  'bug',
#  'build',
#  'bulb',
#  'bulk',
#  'bull',
#  'bulli',
#  'bulli stick',
#  'bun',
#  'bunch',
#  'bunni',
#  'burger',
#  'burn',
#  'burnt',
#  'burst',
#  'busi',
#  'butter',
#  'butter flavor',
#  'butter not',
#  'butteri',
#  'buttermilk',
#  'button',
#  'buy',
#  'buy amazon',
#  'buy anoth',
#  'buy box',
#  'buy brand',
#  'buy bulk',
#  'buy case',
#  'buy coffe',
#  'buy groceri',
#  'buy local',
#  'buy not',
#  'buy one',
#  'buy onlin',
#  'buy pack',
#  'buy product',
#  'buy regular',
#  'buy store',
#  'buy whole',
#  'buyer',
#  'byproduct',
#  'ca',
#  'cabinet',
#  'cacao',
#  'cafe',
#  'caff',
#  'caffein',
#  'caffein free',
#  'cake',
#  'cake mix',
#  'cal',
#  'calcium',
#  'california',
#  'call',
#  'calm',
#  'calori',
#  'calori count',
#  'calori fat',
#  'calori gram',
#  'calori not',
#  'calori per',
#  'came',
#  'came across',
#  'came back',
#  'came quick',
#  'camp',
#  'campbel',
#  'can',
#  'can food',
#  'canada',
#  'cancel',
#  'cancer',
#  'candi',
#  'candi bar',
#  'candi not',
#  'cane',
#  'cane juic',
#  'cane sugar',
#  'canida',
#  'canin',
#  'canist',
#  'cannot',
#  'cannot find',
#  'canola',
#  'cant',
#  'cap',
#  'cappuccino',
#  'capsul',
#  'car',
#  'caramel',
#  'carb',
#  'carbohydr',
#  'carbon',
#  'card',
#  'cardamom',
#  'cardboard',
#  'cardboard box',
#  'care',
#  'care not',
#  'caribou',
#  'carpet',
#  'carri',
#  'carri product',
#  'carrot',
#  'carton',
#  'case',
#  'case amazon',
#  'case not',
#  'cashew',
#  'casserol',
#  'cat',
#  'cat eat',
#  'cat food',
#  'cat like',
#  'cat love',
#  'cat not',
#  'cat would',
#  'catch',
#  'categori',
#  'catnip',
#  'caught',
#  'caus',
#  'caution',
#  'caviar',
#  'cayenn',
#  'celeri',
#  'celesti',
#  'celesti season',
#  'celiac',
#  'celiac diseas',
#  'cent',
#  'cent per',
#  'center',
#  'cereal',
#  'cereal not',
#  'certain',
#  'certain not',
#  'certifi',
#  'certifi organ',
#  'ceylon',
#  'chai',
#  'chai tea',
#  'chain',
#  'chalki',
#  'challeng',
#  'chamomil',
#  'chanc',
#  'chang',
#  'charg',
#  'charm',
#  'cheap',
#  'cheaper',
#  'cheaper buy',
#  'cheapest',
#  'check',
#  'cheddar',
#  'cheerio',
#  'chees',
#  'cheesecak',
#  'cheesi',
#  'chef',
#  'chemic',
#  'chemic tast',
#  'cherri',
#  'cherri flavor',
#  'chew',
#  'chew gum',
#  'chew not',
#  'chewer',
#  'chewi',
#  'chia',
#  'chia seed',
#  'chicken',
#  'chicken breast',
#  'chicken broth',
#  'chicken flavor',
#  'chicken soup',
#  'chicori',
#  'chihuahua',
#  'child',
#  'childhood',
#  'children',
#  'chile',
#  'chili',
#  'chill',
#  'china',
#  'chines',
#  'chip',
#  'chip ahoy',
#  'chip cooki',
#  'chip not',
#  'chipotl',
#  'chocol',
#  'chocol bar',
#  'chocol cake',
#  'chocol chip',
#  'chocol cover',
#  'chocol flavor',
#  'chocol lover',
#  'chocol milk',
#  'chocol not',
#  'chocol peanut',
#  'chocol tast',
#  'chocolatey',
#  'chocolati',
#  'choic',
#  'choke',
#  'cholesterol',
#  'choos',
#  'chop',
#  'chose',
#  'chow',
#  'chowder',
#  'christma',
#  'christma gift',
#  'chunk',
#  'chunki',
#  'cider',
#  'cinnamon',
#  'cinnamon flavor',
#  'citi',
#  'citric',
#  'citric acid',
#  'citrus',
#  'claim',
#  'clam',
#  'class',
#  'classic',
#  'clean',
#  'cleaner',
#  'clear',
#  'click',
#  'close',
#  'closer',
#  'closest',
#  'cloth',
#  'clove',
#  'cloy',
#  'club',
#  'clump',
#  'cluster',
#  'co',
#  'coars',
#  'coast',
#  'coat',
#  'cocktail',
#  'coco',
#  'cocoa',
#  'cocoa powder',
#  'coconut',
#  'coconut flavor',
#  'coconut milk',
#  'coconut oil',
#  'coconut water',
#  'code',
#  'coff',
#  'coffe',
#  'coffe also',
#  'coffe bean',
#  'coffe best',
#  'coffe coffe',
#  'coffe cup',
#  'coffe drink',
#  'coffe drinker',
#  'coffe ever',
#  'coffe everi',
#  'coffe flavor',
#  'coffe good',
#  'coffe great',
#  'coffe ground',
#  'coffe like',
#  'coffe love',
#  'coffe lover',
#  'coffe machin',
#  'coffe make',
#  'coffe maker',
#  'coffe morn',
#  'coffe no',
#  'coffe not',
#  'coffe one',
#  'coffe peopl',
#  'coffe pod',
#  'coffe realli',
#  'coffe shop',
#  'coffe smooth',
#  'coffe strong',
#  'coffe tast',
#  'coffe tea',
#  'coffe tri',
#  'coffe use',
#  'coffe would',
#  'coke',
#  'cola',
#  'cold',
#  'cold water',
#  'collect',
#  'colleg',
#  'colombian',
#  'color',
#  'columbian',
#  'combin',
#  'combo',
#  'come',
#  'come across',
#  'come back',
#  'come close',
#  'comfort',
#  'comment',
#  'commerci',
#  'commit',
#  'common',
#  'communiti',
#  'compani',
#  'compani make',
#  'compani not',
#  'compar',
#  'comparison',
#  'compet',
#  'competit',
#  'complain',
#  'complaint',
#  'complement',
#  'complet',
#  'complex',
#  'compliment',
#  'compon',
#  'compost',
#  'compromis',
#  'con',
#  'concentr',
#  'concept',
#  'concern',
#  'concoct',
#  'condiment',
#  'condit',
#  'condition',
#  'cone',
#  'confid',
#  'confirm',
#  'confus',
#  'connoisseur',
#  'conscious',
#  'consid',
#  'consider',
#  'consist',
#  'constant',
#  'constip',
#  'consum',
#  'consumpt',
#  'contact',
#  'contain',
#  'contain no',
#  'contamin',
#  'content',
#  'continu',
#  'continu buy',
#  'continu order',
#  'continu purchas',
#  'continu use',
#  'contribut',
#  'control',
#  'conveni',
#  'convert',
#  'convinc',
#  'cook',
#  'cook time',
#  'cooker',
#  'cooki',
#  'cooki not',
#  'cooki tast',
#  'cool',
#  'cooler',
#  'core',
#  'corn',
#  'corn syrup',
#  'cornbread',
#  'corner',
#  'correct',
#  'cost',
#  'cost much',
#  'costco',
#  'cotton',
#  'cough',
#  'could',
#  'could buy',
#  'could eat',
#  'could find',
#  'could get',
#  'could make',
#  'could not',
#  'could tast',
#  'could use',
#  'count',
#  'count box',
#  'counter',
#  'countri',
#  'coupl',
#  'coupl day',
#  'coupl month',
#  'coupl time',
#  'coupl week',
#  'coupl year',
#  'coupon',
#  'cours',
#  'cours not',
#  'couscous',
#  'cover',
#  'cow',
#  'cowork',
#  'crab',
#  'crack',
#  'cracker',
#  'cramp',
#  'cranberri',
#  'crap',
#  'crash',
#  'crave',
#  'crazi',
#  'cream',
#  'cream chees',
#  'cream sugar',
#  'creamer',
#  'creami',
#  'creat',
#  'creativ',
#  'credit',
#  'crema',
#  'creme',
#  'cri',
#  'crisp',
#  'crispi',
#  'critic',
#  'crocker',
#  'cross',
#  'crumb',
#  'crumbl',
#  'crunch',
#  'crunchi',
#  'crush',
#  'crust',
#  'crystal',
#  'crystal light',
#  'cube',
#  'cuisin',
#  'cultur',
#  'cup',
#  'cup coffe',
#  'cup day',
#  'cup hot',
#  'cup not',
#  'cup tea',
#  'cup water',
#  'cupboard',
#  'cupcak',
#  'cure',
#  'curious',
#  'current',
#  'curri',
#  'custom',
#  'custom servic',
#  'cut',
#  'cut back',
#  'cute',
#  'cycl',
#  'dad',
#  'daili',
#  'dairi',
#  'damag',
#  'dandruff',
#  'danger',
#  'dark',
#  'dark chocol',
#  'dark roast',
#  'darker',
#  'darn',
#  'dash',
#  'date',
#  'daughter',
#  'daughter love',
#  'davidson',
#  'day',
#  'day ago',
#  'day later',
#  'day love',
#  'day not',
#  'day order',
#  'de',
#  'dead',
#  'deal',
#  'death',
#  'decad',
#  'decaf',
#  'decaf coffe',
#  'decaffein',
#  'decemb',
#  'decent',
#  'decid',
#  'decid buy',
#  ...]

# %%
summary_final_bow_vec.get_shape()
# Out:
# (355850, 5000)

# %%
text_final_bow_vec.get_shape()
# Out:
# (355850, 5000)

# %%
summary_tfidf.get_shape()
# Out:
# (355850, 5000)

# %%
y=final['Score']
y.columns=['idx','Score']
y = pd.DataFrame(y)
y
# Out:
#         Score
# 138686      4
# 476617      5
# 22621       5
# 22620       2
# 157850      5
# ...       ...
# 178145      5
# 173675      5
# 204727      5
# 5259        5
# 302474      5
#
# [355850 rows x 1 columns]

# %%
y.Score.loc[y.Score<3]=0
y.Score.loc[y.Score>3]=1
y
# Out:
#         Score
# 138686      1
# 476617      1
# 22621       1
# 22620       0
# 157850      1
# ...       ...
# 178145      1
# 173675      1
# 204727      1
# 5259        1
# 302474      1
#
# [355850 rows x 1 columns]

# %%
# Train test split
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(text_tfidf,y,train_size=0.7,random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score as score
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV

params = {'alpha':range(1,15)}
f1score = make_scorer(score)

clf = MultinomialNB()
clf2 = RandomizedSearchCV(clf,params,scoring=f1score,verbose=5,random_state=42)
#clf.fit(text_tfidf,y)

# %%
clf2.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] alpha=10 ........................................................
# [CV] ............................ alpha=10, score=0.932, total=   0.1s
# [CV] alpha=10 ........................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ............................ alpha=10, score=0.934, total=   0.1s
# [CV] alpha=10 ........................................................
# [CV] ............................ alpha=10, score=0.933, total=   0.1s
# [CV] alpha=10 ........................................................
# [CV] ............................ alpha=10, score=0.932, total=   0.1s
# [CV] alpha=10 ........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................ alpha=10, score=0.934, total=   0.1s
# [CV] alpha=12 ........................................................
# [CV] ............................ alpha=12, score=0.931, total=   0.1s
# [CV] alpha=12 ........................................................
# [CV] ............................ alpha=12, score=0.932, total=   0.1s
# [CV] alpha=12 ........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................ alpha=12, score=0.931, total=   0.1s
# [CV] alpha=12 ........................................................
# [CV] ............................ alpha=12, score=0.930, total=   0.1s
# [CV] alpha=12 ........................................................
# [CV] ............................ alpha=12, score=0.931, total=   0.1s
# [CV] alpha=1 .........................................................
# [CV] ............................. alpha=1, score=0.940, total=   0.1s
# [CV] alpha=1 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=1, score=0.941, total=   0.1s
# [CV] alpha=1 .........................................................
# [CV] ............................. alpha=1, score=0.940, total=   0.1s
# [CV] alpha=1 .........................................................
# [CV] ............................. alpha=1, score=0.940, total=   0.1s
# [CV] alpha=1 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=1, score=0.941, total=   0.1s
# [CV] alpha=13 ........................................................
# [CV] ............................ alpha=13, score=0.930, total=   0.1s
# [CV] alpha=13 ........................................................
# [CV] ............................ alpha=13, score=0.931, total=   0.1s
# [CV] alpha=13 ........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................ alpha=13, score=0.931, total=   0.1s
# [CV] alpha=13 ........................................................
# [CV] ............................ alpha=13, score=0.930, total=   0.1s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] alpha=13 ........................................................
# [CV] ............................ alpha=13, score=0.931, total=   0.1s
# [CV] alpha=6 .........................................................
# [CV] ............................. alpha=6, score=0.936, total=   0.1s
# [CV] alpha=6 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=6, score=0.937, total=   0.1s
# [CV] alpha=6 .........................................................
# [CV] ............................. alpha=6, score=0.936, total=   0.1s
# [CV] alpha=6 .........................................................
# [CV] ............................. alpha=6, score=0.936, total=   0.1s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] alpha=6 .........................................................
# [CV] ............................. alpha=6, score=0.937, total=   0.1s
# [CV] alpha=9 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=9, score=0.933, total=   0.1s
# [CV] alpha=9 .........................................................
# [CV] ............................. alpha=9, score=0.934, total=   0.1s
# [CV] alpha=9 .........................................................
# [CV] ............................. alpha=9, score=0.934, total=   0.1s
# [CV] alpha=9 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=9, score=0.933, total=   0.1s
# [CV] alpha=9 .........................................................
# [CV] ............................. alpha=9, score=0.934, total=   0.1s
# [CV] alpha=3 .........................................................
# [CV] ............................. alpha=3, score=0.938, total=   0.1s
# [CV] alpha=3 .........................................................
# [CV] ............................. alpha=3, score=0.939, total=   0.1s
# [CV] alpha=3 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=3, score=0.939, total=   0.1s
# [CV] alpha=3 .........................................................
# [CV] ............................. alpha=3, score=0.938, total=   0.1s
# [CV] alpha=3 .........................................................
# [CV] ............................. alpha=3, score=0.940, total=   0.1s
# [CV] alpha=2 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=2, score=0.939, total=   0.1s
# [CV] alpha=2 .........................................................
# [CV] ............................. alpha=2, score=0.940, total=   0.1s
# [CV] alpha=2 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=2, score=0.939, total=   0.1s
# [CV] alpha=2 .........................................................
# [CV] ............................. alpha=2, score=0.939, total=   0.1s
# [CV] alpha=2 .........................................................
# [CV] ............................. alpha=2, score=0.940, total=   0.1s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] alpha=14 ........................................................
# [CV] ............................ alpha=14, score=0.929, total=   0.1s
# [CV] alpha=14 ........................................................
# [CV] ............................ alpha=14, score=0.930, total=   0.1s
# [CV] alpha=14 ........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................ alpha=14, score=0.930, total=   0.1s
# [CV] alpha=14 ........................................................
# [CV] ............................ alpha=14, score=0.929, total=   0.1s
# [CV] alpha=14 ........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................ alpha=14, score=0.930, total=   0.1s
# [CV] alpha=5 .........................................................
# [CV] ............................. alpha=5, score=0.936, total=   0.1s
# [CV] alpha=5 .........................................................
# [CV] ............................. alpha=5, score=0.938, total=   0.1s
# [CV] alpha=5 .........................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ............................. alpha=5, score=0.937, total=   0.1s
# [CV] alpha=5 .........................................................
# [CV] ............................. alpha=5, score=0.937, total=   0.1s
# [CV] alpha=5 .........................................................
# [CV] ............................. alpha=5, score=0.938, total=   0.1s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    5.2s finished
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# RandomizedSearchCV(estimator=MultinomialNB(),
#                    param_distributions={'alpha': range(1, 15)}, random_state=42,
#                    scoring=make_scorer(f1_score), verbose=5)

# %%
clf2.best_params_
# Out:
# {'alpha': 1}

# %%
# Texting Phase
# Clean the review text by removing stop words, punctuations etc.
text="""bad taste. won't reccomend this to anyone"""
text= removeHTML(text)#removes html tags and attributes
text= subsitute(text)#converts short words to normal words
text= removePunctuation(text).strip()#removes punctuation and alphanumeric words
text = ' '.join(ele for ele in text.split() if ele not in stopwords)
test_review=text.strip()
test_review
# Out:
# 'bad taste not reccomend anyone'

# %%
# Converting the review to its stem form
words = test_review.split()
test_review = ' '.join([snbstemmer.stem(w) for w in words])
test_review
# Out:
# 'bad tast not reccomend anyon'

# %%
test = [test_review]
test= tfidf_text.transform(test)
test
# Out:
# <1x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>

# %%
a=clf4.predict_proba(test)
a[0][1]
# Out:
# 0.050352998456587215

# %%
s = "{:.2f}".format(a[][0])
s
# Out:
#   File "<ipython-input-73-cc88ddefbfc3>", line 1
#     s = "{:.2f}".format(a[][0])
#                           ^
# SyntaxError: invalid syntax

# %%
yhat = clf2.predict(xtest)

# %%
result = pd.DataFrame(yhat)
result
# Out:
#         0
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
# ...    ..
# 106751  1
# 106752  1
# 106753  1
# 106754  1
# 106755  1
#
# [106756 rows x 1 columns]

# %%
score(ytest,yhat)
# Out:
# 0.9398788972725651

# %%
from sklearn.linear_model import LogisticRegression

clf3= LogisticRegression()
params={'C':[3,4,5,6,7,8]}
clf4 = RandomizedSearchCV(clf3,params,scoring=f1score,random_state=42,verbose=10)

# %%
clf4.fit(xtrain,ytrain)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:282: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] C=3 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.8s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=3, score=0.961, total=   2.9s
# [CV] C=3 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.6s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=3, score=0.961, total=   2.8s
# [CV] C=3 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    8.6s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=3, score=0.961, total=   3.0s
# [CV] C=3 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   11.5s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=3, score=0.961, total=   2.9s
# [CV] C=3 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   14.4s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=3, score=0.962, total=   2.9s
# [CV] C=4 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   17.3s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=4, score=0.961, total=   2.9s
# [CV] C=4 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   20.3s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=4, score=0.961, total=   3.0s
# [CV] C=4 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   23.1s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=4, score=0.961, total=   2.9s
# [CV] C=4 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   26.2s remaining:    0.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=4, score=0.961, total=   3.0s
# [CV] C=4 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=4, score=0.962, total=   2.9s
# [CV] C=5 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=5, score=0.961, total=   3.0s
# [CV] C=5 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=5, score=0.961, total=   2.8s
# [CV] C=5 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=5, score=0.961, total=   3.0s
# [CV] C=5 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=5, score=0.961, total=   2.9s
# [CV] C=5 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=5, score=0.962, total=   2.9s
# [CV] C=6 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=6, score=0.961, total=   2.8s
# [CV] C=6 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=6, score=0.961, total=   2.9s
# [CV] C=6 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=6, score=0.961, total=   2.9s
# [CV] C=6 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=6, score=0.961, total=   2.9s
# [CV] C=6 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=6, score=0.962, total=   3.0s
# [CV] C=7 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=7, score=0.961, total=   2.9s
# [CV] C=7 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=7, score=0.961, total=   2.9s
# [CV] C=7 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=7, score=0.961, total=   2.9s
# [CV] C=7 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=7, score=0.961, total=   2.9s
# [CV] C=7 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=7, score=0.961, total=   2.9s
# [CV] C=8 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=8, score=0.961, total=   2.9s
# [CV] C=8 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=8, score=0.961, total=   2.8s
# [CV] C=8 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=8, score=0.960, total=   2.9s
# [CV] C=8 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=8, score=0.962, total=   3.0s
# [CV] C=8 .............................................................
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.5min finished
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# [CV] ................................. C=8, score=0.961, total=   3.0s
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# RandomizedSearchCV(estimator=LogisticRegression(),
#                    param_distributions={'C': [3, 4, 5, 6, 7, 8]},
#                    random_state=42, scoring=make_scorer(f1_score), verbose=10)

# %%
clf4.best_estimator_
# Out:
# LogisticRegression(C=3)

# %%
yhat_logit= clf4.predict(xtest)

# %%
score(ytest,yhat_logit)
# Out:
# 0.9617690826330532

# %%
clf4 = LogisticRegression(C=3)
clf4.fit(xtrain,ytrain)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\admin\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=3)

# %%
import pickle

tfidf_file = 'tfidf_vectorizer.pkl'
lr_file = 'LR_model.pkl'

with open(tfidf_file,'wb') as file:
    pickle.dump(tfidf_text,file)
    
with open(lr_file,'wb') as file:
    pickle.dump(clf4,file)

# %%
clf4.predict()
